# %% [markdown]
# # Latam Challenge
#
# ## 1. Exploracion de los datos
#
# Antes de empezar a desarrollar los ejercicios, se realizó una exploración de los datos donde se leyó la documentación oficial del API de twitter para entender mejor la estructura de los datos. Además, también se extrajo unos ejemplos de los datos a analizar. Finalmente, como se muestra abajo, se extrajeron algunos datos como la cantidad de filas, columnas, y el tipo de cada variable.
#
# Se identificó que, a raiz de los problemas presentados, las columnas de interes serían "date", "user", "content", y "mentioned_users".

# %%
import pandas as pd

file_path = "../farmers-protest-tweets-2021-2-4.json"
df = pd.read_json(file_path, lines=True)
print(df.shape)
df.dtypes
# Out:
# (117407, 21)
# url                             object
# date               datetime64[ns, UTC]
# content                         object
# renderedContent                 object
# id                               int64
# user                            object
# outlinks                        object
# tcooutlinks                     object
# replyCount                       int64
# retweetCount                     int64
# likeCount                        int64
# quoteCount                       int64
# conversationId                   int64
# lang                            object
# source                          object
# sourceUrl                       object
# sourceLabel                     object
# media                           object
# retweetedTweet                 float64
# quotedTweet                     object
# mentionedUsers                  object
# dtype: object

# %%
from typing import List, Tuple
import re
import json
from collections import Counter

# %%
    
# Regex pattern for emojis
emoji_pattern = re.compile(r'[\U0001F300-\U0001F6FF\U0001F900-\U0001F9FF\u2600-\u26FF\u2700-\u27BF]', flags=re.UNICODE)
emojis_dict = {}
with open(file_path) as f:
        for jsonObj in f:
            tweetDict = json.loads(jsonObj)
            # Uses the regex previously created to find all the emojis in the tweet content
            emojis = emoji_pattern.findall(tweetDict['content'])
            for emoji in emojis:
                # Sums 1 to the quantity of appereances of the emoji if it already exists
                if emojis_dict.get(emoji) is not None:
                    emojis_dict[emoji] = emojis_dict[emoji] + 1
                # Adds the emoji to the dictionary and sets the value to 1 if it did not exist
                else:
                    emojis_dict[emoji] = 1


# Sorts the dictionary by values in descending order
#emojis_dict = sorted(emojis_dict.items(), key=lambda x: x[1], reverse=True)
items10 = [(x, y) for x, y in emojis_dict.items()[:10]]
minval = min(items10, lambda x: x[1])
minindex = index(minval, lambda x: x[1])
for x, y in emojis_dict.items()[10:]:
    if y < minval:
        items10[minindex] = (x, y)
        minval = min(items10, lambda x: x[1])
        minindex = index(minval, lambda x: x[1])

# Extracts the top 10 emojis
emojis_dict = emojis_dict[:10]
emojis_dict
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 20
#      15                     emojis_dict[emoji] = 1
#      18 # Sorts the dictionary by values in descending order
#      19 #emojis_dict = sorted(emojis_dict.items(), key=lambda x: x[1], reverse=True)
# ---> 20 items10 = [(x, y) for x, y in emojis_dict.items()[:10]]
#      21 minval = min(items10, lambda x: x[1])
#      22 minindex = index(minval, lambda x: x[1])
#
# TypeError: 'dict_items' object is not subscriptable

# %%
# Regex pattern for emojis
emoji_pattern = re.compile(r'[\U0001F300-\U0001F6FF\U0001F900-\U0001F9FF\u2600-\u26FF\u2700-\u27BF]', flags=re.UNICODE)

emojis_dict = {}
with open(file_path) as f:
        for jsonObj in f:
            tweetDict = json.loads(jsonObj)
            # Uses the regex previously created to find all the emojis in the tweet content
            emojis = emoji_pattern.findall(tweetDict['content'])
            for emoji in emojis:
                # Sums 1 to the quantity of appereances of the emoji if it already exists
                if emojis_dict.get(emoji) is not None:
                    emojis_dict[emoji] = emojis_dict[emoji] + 1
                # Adds the emoji to the dictionary and sets the value to 1 if it did not exist
                else:
                    emojis_dict[emoji] = 1


# Sorts the dictionary by values in descending order
emojis_dict = sorted(emojis_dict.items(), key=lambda x: x[1], reverse=True)

# Extracts the top 10 emojis
emojis_dict = emojis_dict[:10]
emojis_dict
# Out:
# [('🙏', 7286),
#  ('😂', 3072),
#  ('🚜', 2972),
#  ('✊', 2411),
#  ('🌾', 2363),
#  ('🏻', 2080),
#  ('❤', 1779),
#  ('🤣', 1668),
#  ('🏽', 1218),
#  ('👇', 1108)]

# %% [markdown]
# ## 2.1 Challenge 1

# %%
from q1_memory import q1_memory
from q1_time import q1_time
from q2_memory import q2_memory
from q2_time import q2_time
from q3_memory import q3_memory
from q3_time import q3_time
import json
import cProfile
from datetime import datetime
from collections import defaultdict
file_path = "../farmers-protest-tweets-2021-2-4.json"

# %% [markdown]
# Para el reto 1 en optimización de tiempo, se usó la libreria Pandas. Esta libreria es reconocida por su facilidad de uso y optimización para casos de manejo y transformación de datos en python. Es por ello que nos permite usar métodos similares a los usados por estructuras de tablas, que fácilita el trabajo en este problema.
#
# Usando funciones de gropyby, se extrajeron las diez fechas con más posts. Luego, con esta misma función, se extrajeron los posts por usuario por día.
# Teniendo ambas cosas, es posible sacar la respuesta al challenge usando la función idxmax, que nos da el indice del usuario con más posts en cada uno de los 10 días con más posts.

# %%
res_1_time = q1_time(file_path)
res_1_time
# Out:
# [(datetime.date(2021, 2, 12), 'RanbirS00614606'),
#  (datetime.date(2021, 2, 13), 'MaanDee08215437'),
#  (datetime.date(2021, 2, 17), 'RaaJVinderkaur'),
#  (datetime.date(2021, 2, 16), 'jot__b'),
#  (datetime.date(2021, 2, 14), 'rebelpacifist'),
#  (datetime.date(2021, 2, 18), 'neetuanjle_nitu'),
#  (datetime.date(2021, 2, 15), 'jot__b'),
#  (datetime.date(2021, 2, 20), 'MangalJ23056160'),
#  (datetime.date(2021, 2, 23), 'Surrypuria'),
#  (datetime.date(2021, 2, 19), 'Preetm91')]

# %% [markdown]
# En cuanto a la optimización por memoria, se decidió uno usar pandas para, en su reemplazo, usar estructuras de datos nativas y así bajar el consumo de memoria. Adicionalmente, se hace la lectura de los datos línea por línea y solo guardando en variables permanentes las variables que nos interesan, permitiendo así mayores ahorros de memoria.
#
# Las estructuras de datos usadas fueron principalmente diccionarios, donde a medida que se leía cada JSON del archivo, se iba llevando la cuenta de cuántos posts tenía el día en específico y cuántos posts tenía cada usuario en cada día. De esta manera, mientras se leían los datos también se iba procesando la iformación al mismo tiempo.
#
# También se hace uso de la mayor cantidad de operaciones in-place para poder ahorrar en memoria de variables.

# %%
res_1_mem = q1_memory(file_path)
res_1_mem
# Out:
# [(datetime.date(2021, 2, 12), 'RanbirS00614606'),
#  (datetime.date(2021, 2, 13), 'MaanDee08215437'),
#  (datetime.date(2021, 2, 17), 'RaaJVinderkaur'),
#  (datetime.date(2021, 2, 16), 'jot__b'),
#  (datetime.date(2021, 2, 14), 'rebelpacifist'),
#  (datetime.date(2021, 2, 18), 'neetuanjle_nitu'),
#  (datetime.date(2021, 2, 15), 'jot__b'),
#  (datetime.date(2021, 2, 20), 'MangalJ23056160'),
#  (datetime.date(2021, 2, 23), 'Surrypuria'),
#  (datetime.date(2021, 2, 19), 'Preetm91')]

# %% [markdown]
# ## 2.2 Análisis de resultados
#
# Despues de correr los dos métodos, como se ve en las siguientes dos celdas, se puede apreciar que las optimizaciones para ambos están funcionando. Para el de tiempo, su tiempo de ejecución en promedio fue de 6.5 segundos, mientras que para el de espacio fue de 55 segundos.
#
# Por otro lado, para el de memoria su uso fue de aproximadamente 139 MiB, mientras que para el de tiempo el uso fue de aproximadamente 1600 MiB

# %%
cProfile.run('q1_time(file_path=file_path)')
# Out:
# Filename: c:\Users\sestupinan\Documents\latam\latam-challenge-sestupinan\src\q1_time.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#      7    107.0 MiB    107.0 MiB           1   @profile
#      8                                         def q1_time(file_path: str) -> List[Tuple[datetime.date, str]]:
#      9
#     10                                             # Data loading
#     11   1553.1 MiB   1446.2 MiB           1       df = pd.read_json(file_path, lines=True)
#     12
#     13                                             # Create a date column using the datetime provided
#     14   1558.7 MiB      5.6 MiB           1       df['date_t'] = pd.to_datetime(df['date']).dt.date
#     15
#     16                                             # Compute the top 10 days with the most posts
#     17   1559.1 MiB      0.3 MiB           1       max_days = df.groupby("date_t").size().nlargest(10)
#     18
#     19                                             # Compute the top 10 days with the most posts
#     20   1560.2 MiB      1.1 MiB           1       df_usernames = pd.concat([df[['date_t']], df['user'].str['username']], axis = 1)
#     21
#     22                                             # Compute the top users with the most posts per day
#     23   1566.5 MiB      6.3 MiB           1       max_users = df_usernames.groupby(["date_t","user"]).size()
#     24
#     25                                             # Extract the top users only for the top 10 days
#     26   1566.5 MiB      0.0 MiB           1       most_repeated_users_per_day = []
#     27   1566.9 MiB      0.0 MiB          11       for date in max_days.index:
#     28   1566.9 MiB      0.4 MiB          10           most_repeated_users_per_day.append((date, max_users[date].idxmax()))
#     29   1566.9 MiB      0.0 MiB           1       return most_repeated_users_per_day
#
#
#          906475 function calls (905512 primitive calls) in 6.920 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:100(acquire)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:1022(_find_and_load)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:1038(_gcd_import)
#        13    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:125(release)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:165(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:169(__enter__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:173(__exit__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:198(cb)
#        50    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:244(_verbose_message)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:357(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:71(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:746(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:826(find_spec)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:893(__enter__)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:897(__exit__)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:921(_find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:968(_sanity_check)
#         1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:987(_find_and_load_unlocked)
#        50    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:119(<listcomp>)
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1356(_path_importer_cache)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1399(_get_spec)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1431(find_spec)
#        10    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1536(find_spec)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:67(_relax_case)
#        50    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:96(_path_join)
#         2    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000    6.920    6.920 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         1    0.000    0.000    0.002    0.002 __init__.py:108(import_module)
#         1    0.000    0.000    0.000    0.000 __init__.py:24(_module_matches_namespace)
#       179    0.000    0.000    0.000    0.000 __init__.py:34(using_copy_on_write)
#        48    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#        24    0.000    0.000    0.000    0.000 __init__.py:55(using_pyarrow_string_dtype)
#         1    0.000    0.000    0.000    0.000 __init__.py:57(find_spec)
#         1    0.000    0.000    0.000    0.000 __init__.py:89(find_spec)
#         1    0.000    0.000    0.000    0.000 __init__.py:96(<lambda>)
#        19    0.000    0.000    0.000    0.000 _asarray.py:108(<setcomp>)
#        19    0.000    0.000    0.001    0.000 _asarray.py:27(require)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:262(__subclasshook__)
#         5    0.000    0.000    0.000    0.000 _collections_abc.py:283(__subclasshook__)
#        21    0.000    0.000    0.000    0.000 _collections_abc.py:315(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:362(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:381(__subclasshook__)
#        57    0.000    0.000    0.000    0.000 _collections_abc.py:409(__subclasshook__)
#         9    0.000    0.000    0.000    0.000 _collections_abc.py:78(_check_methods)
#         1    0.000    0.000    0.000    0.000 _decorators.py:325(wrapper)
#        67    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#        67    0.000    0.000    0.000    0.000 _dtype.py:330(_name_includes_bit_suffix)
#        67    0.000    0.000    0.001    0.000 _dtype.py:346(_name_get)
#         4    0.000    0.000    0.000    0.000 _internal.py:920(npy_ctypes_check)
#         1    0.000    0.000    5.038    5.038 _json.py:1033(_get_object_parser)
#         2    0.000    0.000    0.000    0.000 _json.py:1060(close)
#         2    0.000    0.000    0.000    0.000 _json.py:1113(__enter__)
#         2    0.000    0.000    0.000    0.000 _json.py:1116(__exit__)
#         1    0.000    0.000    0.000    0.000 _json.py:1138(__init__)
#         1    0.000    0.000    5.037    5.037 _json.py:1185(parse)
#         1    0.000    0.000    0.023    0.023 _json.py:1199(_convert_axes)
#        23    0.001    0.000    0.036    0.002 _json.py:1223(_try_convert_data)
#         3    0.000    0.000    0.170    0.057 _json.py:1315(_try_convert_to_date)
#         1    0.109    0.109    4.625    4.625 _json.py:1397(_parse)
#         2    0.000    0.000    0.355    0.178 _json.py:1433(_process_converter)
#        21    0.000    0.000    0.000    0.000 _json.py:1442(<lambda>)
#         1    0.015    0.015    0.390    0.390 _json.py:1463(_try_convert_types)
#        21    0.000    0.000    0.014    0.001 _json.py:1470(<lambda>)
#         1    0.019    0.019    0.266    0.266 _json.py:1473(_try_convert_dates)
#        21    0.000    0.000    0.000    0.000 _json.py:1483(is_ok)
#         1    0.000    0.000    0.149    0.149 _json.py:1505(<lambda>)
#         1    0.054    0.054    6.442    6.442 _json.py:505(read_json)
#         1    0.000    0.000    0.426    0.426 _json.py:827(__init__)
#         1    0.000    0.000    0.423    0.423 _json.py:907(_preprocess_data)
#         1    0.000    0.000    0.002    0.002 _json.py:923(_get_data_from_filepath)
#         1    0.143    0.143    0.627    0.627 _json.py:971(_combine_lines)
#    117409    0.110    0.000    0.295    0.000 _json.py:976(<genexpr>)
#         1    0.083    0.083    0.378    0.378 _json.py:976(<listcomp>)
#         1    0.020    0.020    5.962    5.962 _json.py:991(read)
#         1    0.000    0.000    0.000    0.000 _methods.py:39(_amax)
#         1    0.000    0.000    0.000    0.000 _methods.py:47(_sum)
#        17    0.000    0.000    0.000    0.000 _methods.py:55(_any)
#        42    0.000    0.000    0.000    0.000 _methods.py:61(_all)
#         2    0.000    0.000    0.000    0.000 _mixins.py:278(__getitem__)
#         1    0.000    0.000    0.000    0.000 _mixins.py:78(method)
#         1    0.000    0.000    0.002    0.002 _optional.py:85(import_optional_dependency)
#         1    0.000    0.000    0.000    0.000 _parser.py:1056(_could_be_tzname)
#         1    0.000    0.000    0.000    0.000 _parser.py:186(__iter__)
#         2    0.000    0.000    0.000    0.000 _parser.py:189(__next__)
#         1    0.000    0.000    0.000    0.000 _parser.py:199(split)
#         3    0.000    0.000    0.000    0.000 _parser.py:203(isword)
#         1    0.000    0.000    0.000    0.000 _parser.py:221(__init__)
#         1    0.000    0.000    0.000    0.000 _parser.py:319(jump)
#         1    0.000    0.000    0.000    0.000 _parser.py:322(weekday)
#         1    0.000    0.000    0.000    0.000 _parser.py:329(month)
#         1    0.000    0.000    0.000    0.000 _parser.py:342(ampm)
#         1    0.000    0.000    0.000    0.000 _parser.py:395(__init__)
#         1    0.000    0.000    0.000    0.000 _parser.py:62(__init__)
#         1    0.000    0.000    0.000    0.000 _parser.py:666(_parse)
#         2    0.000    0.000    0.000    0.000 _parser.py:77(get_token)
#         3    0.000    0.000    0.000    0.000 _strptime.py:238(pattern)
#         3    0.000    0.000    0.000    0.000 _strptime.py:26(_getlang)
#         3    0.000    0.000    0.012    0.004 _strptime.py:261(compile)
#         3    0.000    0.000    0.012    0.004 _strptime.py:309(_strptime)
#         3    0.000    0.000    0.012    0.004 _strptime.py:565(_strptime_datetime)
#         4    0.000    0.000    0.000    0.000 _validators.py:226(validate_bool_kwarg)
#         1    0.000    0.000    0.000    0.000 _validators.py:450(check_dtype_backend)
#       155    0.000    0.000    0.001    0.000 abc.py:117(__instancecheck__)
#    134/18    0.000    0.000    0.001    0.000 abc.py:121(__subclasscheck__)
#         1    0.000    0.000    0.003    0.003 accessor.py:188(__init__)
#         1    0.003    0.003    0.003    0.003 accessor.py:207(_validate)
#         2    0.000    0.000    0.003    0.002 accessor.py:220(__get__)
#         1    0.000    0.000    0.214    0.214 accessor.py:248(__getitem__)
#         1    0.000    0.000    0.000    0.000 accessor.py:255(_wrap_result)
#         1    0.000    0.000    0.012    0.012 accessor.py:95(_getter)
#         1    0.000    0.000    0.000    0.000 accessors.py:59(__init__)
#         1    0.000    0.000    0.000    0.000 accessors.py:611(__new__)
#         1    0.000    0.000    0.000    0.000 accessors.py:70(_get_values)
#         1    0.000    0.000    0.012    0.012 accessors.py:88(_delegate_property_get)
#         3    0.000    0.000    0.000    0.000 algorithms.py:106(_ensure_data)
#        13    0.000    0.000    0.002    0.000 algorithms.py:1131(take)
#        20    0.000    0.000    0.001    0.000 algorithms.py:1248(searchsorted)
#         3    0.002    0.001    0.051    0.017 algorithms.py:1452(safe_sort)
#         6    0.000    0.000    0.000    0.000 algorithms.py:184(_reconstruct_data)
#         3    0.000    0.000    0.000    0.000 algorithms.py:217(_ensure_arraylike)
#         3    0.000    0.000    0.003    0.001 algorithms.py:262(_get_hashtable_algo)
#         3    0.003    0.001    0.003    0.001 algorithms.py:280(_check_object_for_strings)
#         3    0.039    0.013    0.042    0.014 algorithms.py:548(factorize_array)
#         3    0.001    0.000    0.095    0.032 algorithms.py:610(factorize)
#         1    0.000    0.000    0.000    0.000 api.py:102(<listcomp>)
#         1    0.000    0.000    0.000    0.000 api.py:106(_get_distinct_objs)
#         1    0.000    0.000    0.000    0.000 api.py:120(_get_combined_index)
#         1    0.000    0.000    0.000    0.000 api.py:202(union_indexes)
#        12    0.000    0.000    0.000    0.000 api.py:386(default_index)
#         1    0.000    0.000    0.000    0.000 api.py:72(get_objs_combined_axis)
#         1    0.000    0.000    0.000    0.000 array_ops.py:189(_na_arithmetic_op)
#         1    0.000    0.000    0.000    0.000 array_ops.py:288(comparison_op)
#         2    0.000    0.000    0.000    0.000 array_ops.py:352(na_logical_op)
#         2    0.000    0.000    0.000    0.000 array_ops.py:393(logical_op)
#         4    0.000    0.000    0.000    0.000 array_ops.py:410(fill_bool)
#         1    0.000    0.000    0.001    0.001 arraylike.py:253(array_ufunc)
#         1    0.000    0.000    0.000    0.000 arraylike.py:418(_standardize_out_kwarg)
#         1    0.000    0.000    0.001    0.001 arraylike.py:54(__gt__)
#         1    0.000    0.000    0.000    0.000 arraylike.py:76(__or__)
#         1    0.000    0.000    0.001    0.001 arraylike.py:80(__ror__)
#         1    0.000    0.000    0.000    0.000 astype.py:138(_astype_float_to_int_nansafe)
#        32    0.000    0.000    0.004    0.000 astype.py:157(astype_array)
#        32    0.000    0.000    0.009    0.000 astype.py:191(astype_array_safe)
#        32    0.001    0.000    0.004    0.000 astype.py:56(_astype_nansafe)
#         5    0.000    0.000    0.000    0.000 base.py:1010(view)
#         2    0.000    0.000    0.000    0.000 base.py:1045(astype)
#        13    0.000    0.000    0.002    0.000 base.py:1146(take)
#        13    0.000    0.000    0.000    0.000 base.py:1176(_maybe_disallow_fill)
#        33    0.000    0.000    0.000    0.000 base.py:122(_reset_cache)
#         2    0.000    0.000    0.000    0.000 base.py:159(_freeze)
#        13    0.000    0.000    0.000    0.000 base.py:166(__setattr__)
#        32    0.000    0.000    0.000    0.000 base.py:1671(name)
#         1    0.000    0.000    0.000    0.000 base.py:1697(_validate_names)
#         5    0.000    0.000    0.000    0.000 base.py:1765(_get_names)
#         1    0.000    0.000    0.000    0.000 base.py:1768(_set_names)
#         1    0.000    0.000    0.000    0.000 base.py:1809(set_names)
#         1    0.000    0.000    0.000    0.000 base.py:1922(rename)
#         1    0.000    0.000    0.000    0.000 base.py:1979(nlevels)
#        10    0.000    0.000    0.003    0.000 base.py:2159(_drop_level_numbers)
#         4    0.000    0.000    0.000    0.000 base.py:2313(is_unique)
#       726    0.002    0.000    0.002    0.000 base.py:238(construct_from_string)
#         4    0.000    0.000    0.000    0.000 base.py:2744(inferred_type)
#         8    0.000    0.000    0.000    0.000 base.py:2776(_is_multi)
#         3    0.000    0.000    0.000    0.000 base.py:2794(_na_value)
#         1    0.000    0.000    0.000    0.000 base.py:323(_consolidate_inplace)
#         2    0.000    0.000    0.000    0.000 base.py:346(shape)
#         1    0.000    0.000    0.000    0.000 base.py:348(_is_boolean)
#        16    0.000    0.000    0.000    0.000 base.py:363(ndim)
#         1    0.000    0.000    0.214    0.214 base.py:37(_str_getitem)
#        58    0.000    0.000    0.000    0.000 base.py:3777(get_loc)
#         7    0.000    0.000    0.000    0.000 base.py:3809(<genexpr>)
#         4    0.000    0.000    0.001    0.000 base.py:3820(get_indexer)
#         2    0.000    0.000    0.000    0.000 base.py:3955(_get_indexer)
#         4    0.000    0.000    0.000    0.000 base.py:3996(_check_indexing_method)
#         1    0.000    0.000    0.000    0.000 base.py:4191(_validate_positional_slice)
#         1    0.000    0.000    0.000    0.000 base.py:4323(reindex)
#         1    0.000    0.000    0.000    0.000 base.py:4436(_wrap_reindex_result)
#         1    0.000    0.000    0.000    0.000 base.py:4440(_maybe_preserve_names)
#         9    0.000    0.000    0.000    0.000 base.py:448(size)
#         5    0.000    0.000    0.000    0.000 base.py:456(_engine_type)
#        12    0.001    0.000    0.003    0.000 base.py:475(__new__)
#       111    0.000    0.000    0.000    0.000 base.py:5144(_values)
#         7    0.000    0.000    0.000    0.000 base.py:5170(_get_engine_target)
#         1    0.000    0.000    0.000    0.000 base.py:5295(_validate_fill_value)
#         9    0.000    0.000    0.000    0.000 base.py:5323(__contains__)
#       104    0.000    0.000    0.000    0.000 base.py:5373(__getitem__)
#         6    0.000    0.000    0.000    0.000 base.py:540(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:5425(_getitem_slice)
#         2    0.000    0.000    0.000    0.000 base.py:5455(append)
#         2    0.000    0.000    0.000    0.000 base.py:5486(<setcomp>)
#        75    0.003    0.000    0.006    0.000 base.py:549(find)
#         2    0.000    0.000    0.000    0.000 base.py:5491(_concat)
#         2    0.000    0.000    0.000    0.000 base.py:5495(<listcomp>)
#         5    0.000    0.000    0.000    0.000 base.py:5552(equals)
#        12    0.000    0.000    0.000    0.000 base.py:591(_ensure_array)
#        12    0.000    0.000    0.000    0.000 base.py:609(_dtype_to_subclass)
#         2    0.000    0.000    0.001    0.000 base.py:6162(get_indexer_for)
#         1    0.000    0.000    0.001    0.001 base.py:6186(_get_indexer_strict)
#         1    0.000    0.000    0.000    0.000 base.py:6219(_raise_if_missing)
#         8    0.000    0.000    0.000    0.000 base.py:6312(_index_as_unique)
#         3    0.000    0.000    0.000    0.000 base.py:6324(_maybe_downcast_for_indexing)
#         3    0.000    0.000    0.000    0.000 base.py:6394(_should_compare)
#         3    0.000    0.000    0.000    0.000 base.py:6415(_is_comparable_dtype)
#        79    0.001    0.000    0.001    0.000 base.py:649(_simple_new)
#        58    0.000    0.000    0.000    0.000 base.py:6672(_maybe_cast_indexer)
#         4    0.000    0.000    0.000    0.000 base.py:6679(_maybe_cast_listlike_indexer)
#         3    0.000    0.000    0.000    0.000 base.py:6685(_validate_indexer)
#         6    0.000    0.000    0.001    0.000 base.py:674(_with_infer)
#         9    0.000    0.000    0.000    0.000 base.py:675(empty)
#        10    0.000    0.000    0.000    0.000 base.py:680(argmax)
#         1    0.000    0.000    0.000    0.000 base.py:6916(delete)
#         3    0.000    0.000    0.000    0.000 base.py:692(_constructor)
#         1    0.000    0.000    0.001    0.001 base.py:6956(insert)
#         1    0.000    0.000    0.000    0.000 base.py:7031(drop)
#        42    0.000    0.000    0.000    0.000 base.py:74(__len__)
#        90    0.000    0.000    0.001    0.000 base.py:7593(ensure_index)
#         1    0.000    0.000    0.000    0.000 base.py:7652(ensure_has_len)
#        46    0.000    0.000    0.000    0.000 base.py:7688(maybe_extract_name)
#         3    0.000    0.000    0.000    0.000 base.py:7723(_unpack_nested_dtype)
#        48    0.000    0.000    0.001    0.000 base.py:773(_view)
#        23    0.000    0.000    0.000    0.000 base.py:782(_rename)
#         5    0.000    0.000    0.000    0.000 base.py:791(is_)
#        10    0.000    0.000    0.000    0.000 base.py:82(shape)
#       105    0.000    0.000    0.000    0.000 base.py:831(_reset_identity)
#         9    0.000    0.000    0.000    0.000 base.py:836(__iter__)
#        27    0.000    0.000    0.000    0.000 base.py:84(<genexpr>)
#         5    0.000    0.000    0.000    0.000 base.py:842(_engine)
#        34    0.000    0.000    0.000    0.000 base.py:86(_validate_set_axis)
#       124    0.000    0.000    0.000    0.000 base.py:909(__len__)
#        10    0.000    0.000    0.000    0.000 base.py:974(dtype)
#         4    0.000    0.000    0.000    0.000 blocks.py:1249(shape)
#        47    0.000    0.000    0.000    0.000 blocks.py:1253(iget)
#         2    0.000    0.000    0.000    0.000 blocks.py:1262(_slice)
#         3    0.000    0.000    0.001    0.000 blocks.py:1287(take_nd)
#        25    0.000    0.000    0.000    0.000 blocks.py:214(is_extension)
#        22    0.000    0.000    0.000    0.000 blocks.py:219(_can_consolidate)
#        21    0.000    0.000    0.000    0.000 blocks.py:225(_consolidate_key)
#         1    0.000    0.000    0.000    0.000 blocks.py:230(_can_hold_na)
#         3    0.000    0.000    0.000    0.000 blocks.py:253(fill_value)
#         1    0.000    0.000    0.000    0.000 blocks.py:2582(array_values)
#        40    0.000    0.000    0.000    0.000 blocks.py:2645(maybe_coerce_values)
#        20    0.000    0.000    0.000    0.000 blocks.py:266(mgr_locs)
#        61    0.000    0.000    0.000    0.000 blocks.py:2674(get_block_type)
#         8    0.000    0.000    0.000    0.000 blocks.py:2703(new_block_2d)
#        32    0.000    0.000    0.000    0.000 blocks.py:2716(new_block)
#         1    0.000    0.000    0.000    0.000 blocks.py:274(make_block)
#        15    0.000    0.000    0.000    0.000 blocks.py:2795(extend_blocks)
#         4    0.000    0.000    0.000    0.000 blocks.py:2811(ensure_block_shape)
#         3    0.000    0.000    0.000    0.000 blocks.py:292(make_block_same_class)
#         2    0.000    0.000    0.000    0.000 blocks.py:324(slice_block_columns)
#        74    0.000    0.000    0.000    0.000 blocks.py:718(dtype)
#        32    0.000    0.000    0.010    0.000 blocks.py:723(astype)
#         5    0.000    0.000    0.002    0.000 blocks.py:790(copy)
#        41    0.005    0.000    0.006    0.000 cast.py:1157(maybe_infer_to_datetimelike)
#         4    0.000    0.000    0.000    0.000 cast.py:124(maybe_convert_platform)
#         9    0.000    0.000    0.000    0.000 cast.py:1519(construct_1d_arraylike_from_scalar)
#         4    0.000    0.000    0.000    0.000 cast.py:1580(construct_1d_object_array_from_listlike)
#         3    0.000    0.000    0.000    0.000 cast.py:1605(maybe_cast_to_integer_array)
#         2    0.000    0.000    0.000    0.000 cast.py:1763(np_can_hold_element)
#         1    0.000    0.000    0.000    0.000 cast.py:1955(np_can_cast_scalar)
#         1    0.000    0.000    0.000    0.000 cast.py:525(ensure_dtype_can_hold_na)
#         7    0.000    0.000    0.000    0.000 cast.py:551(maybe_promote)
#         2    0.000    0.000    0.000    0.000 cast.py:606(_maybe_promote_cached)
#         2    0.000    0.000    0.000    0.000 cast.py:614(_maybe_promote)
#         1    0.000    0.000    0.000    0.000 cast.py:737(_ensure_dtype_type)
#         1    0.000    0.000    0.000    0.000 cast.py:922(_maybe_infer_dtype_type)
#        22    0.000    0.000    0.000    0.000 cast.py:973(coerce_indexer_dtype)
#         2    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         2    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#         4    0.000    0.000    0.096    0.024 codecs.py:319(decode)
#         6    0.000    0.000    0.000    0.000 common.py:1040(needs_i8_conversion)
#         6    0.000    0.000    0.000    0.000 common.py:1081(is_numeric_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:1117(_maybe_memory_map)
#         3    0.000    0.000    0.000    0.000 common.py:1122(<lambda>)
#         1    0.000    0.000    0.000    0.000 common.py:1151(file_exists)
#         2    0.000    0.000    0.000    0.000 common.py:1163(is_float_dtype)
#         2    0.000    0.000    0.002    0.001 common.py:1165(_is_binary_mode)
#         1    0.000    0.000    0.002    0.002 common.py:1186(_get_binary_io_classes)
#         2    0.000    0.000    0.000    0.000 common.py:1194(<lambda>)
#         3    0.000    0.000    0.000    0.000 common.py:1198(is_bool_dtype)
#         9    0.000    0.000    0.000    0.000 common.py:121(classes)
#         9    0.000    0.000    0.000    0.000 common.py:123(<lambda>)
#         8    0.000    0.000    0.000    0.000 common.py:126(_classes_and_not_datetimelike)
#       111    0.000    0.000    0.000    0.000 common.py:1270(is_1d_only_ea_dtype)
#        32    0.000    0.000    0.003    0.000 common.py:1277(is_extension_array_dtype)
#         8    0.000    0.000    0.000    0.000 common.py:131(<lambda>)
#         2    0.000    0.000    0.000    0.000 common.py:131(close)
#        24    0.000    0.000    0.000    0.000 common.py:1331(is_ea_or_datetimelike_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:1342(is_complex_dtype)
#         6    0.000    0.000    0.000    0.000 common.py:137(is_object_dtype)
#        31    0.000    0.000    0.000    0.000 common.py:1375(_is_dtype)
#        34    0.000    0.000    0.000    0.000 common.py:1399(_get_dtype)
#        17    0.000    0.000    0.000    0.000 common.py:1434(_is_dtype_type)
#       104    0.000    0.000    0.000    0.000 common.py:152(cast_scalar_indexer)
#        38    0.000    0.000    0.000    0.000 common.py:1571(validate_all_hashable)
#        76    0.000    0.000    0.000    0.000 common.py:1590(<genexpr>)
#        67    0.001    0.000    0.005    0.000 common.py:1596(pandas_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:160(is_url)
#         2    0.000    0.000    0.000    0.000 common.py:174(not_none)
#         6    0.000    0.000    0.000    0.000 common.py:178(<genexpr>)
#         5    0.000    0.000    0.000    0.000 common.py:188(_expand_user)
#         9    0.000    0.000    0.000    0.000 common.py:231(asarray_tuplesafe)
#         4    0.000    0.000    0.000    0.000 common.py:248(stringify_path)
#         2    0.000    0.000    0.000    0.000 common.py:292(is_fsspec_url)
#        52    0.000    0.000    0.000    0.000 common.py:301(maybe_iterable_to_list)
#         1    0.000    0.000    0.000    0.000 common.py:304(_get_filepath_or_buffer)
#        19    0.000    0.000    0.000    0.000 common.py:372(apply_if_callable)
#         1    0.000    0.000    0.000    0.000 common.py:515(get_compression_method)
#        27    0.000    0.000    0.000    0.000 common.py:529(is_string_or_object_np_dtype)
#         4    0.000    0.000    0.000    0.000 common.py:535(temp_setattr)
#        25    0.000    0.000    0.000    0.000 common.py:536(is_string_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:550(infer_compression)
#        40    0.000    0.000    0.000    0.000 common.py:568(require_length_match)
#        25    0.000    0.000    0.000    0.000 common.py:572(condition)
#         3    0.000    0.000    0.002    0.001 common.py:62(new_method)
#         2    0.000    0.000    0.000    0.000 common.py:633(is_integer_dtype)
#         1    0.000    0.000    0.002    0.002 common.py:664(get_handle)
#         1    0.000    0.000    0.000    0.000 common.py:686(<lambda>)
#         1    0.000    0.000    0.000    0.000 common.py:80(ensure_str)
#         3    0.000    0.000    0.000    0.000 common.py:81(get_op_result_name)
#         1    0.000    0.000    0.000    0.000 common.py:86(consensus_name_attr)
#        12    0.000    0.000    0.000    0.000 common.py:97(is_bool_indexer)
#         1    0.000    0.000    0.000    0.000 common.py:992(is_numeric_v_string_like)
#         2    0.000    0.000    0.005    0.002 concat.py:157(concat)
#         1    0.000    0.000    0.003    0.003 concat.py:202(_maybe_reindex_columns_na_proxy)
#         2    0.000    0.000    0.001    0.000 concat.py:405(__init__)
#         2    0.000    0.000    0.000    0.000 concat.py:480(_get_ndims)
#         2    0.000    0.000    0.000    0.000 concat.py:494(_clean_keys_and_objs)
#         3    0.000    0.000    0.000    0.000 concat.py:52(concat_compat)
#         2    0.000    0.000    0.000    0.000 concat.py:545(_get_sample_object)
#         1    0.000    0.000    0.000    0.000 concat.py:567(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:579(_sanitize_mixed_ndim)
#         2    0.000    0.000    0.004    0.002 concat.py:622(get_result)
#         1    0.000    0.000    0.000    0.000 concat.py:635(<listcomp>)
#         2    0.000    0.000    0.000    0.000 concat.py:693(_get_result_dim)
#         2    0.000    0.000    0.001    0.000 concat.py:699(new_axes)
#         2    0.000    0.000    0.001    0.000 concat.py:702(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:707(_get_comb_axis)
#         2    0.000    0.000    0.001    0.000 concat.py:717(_get_concat_axis)
#         1    0.000    0.000    0.000    0.000 concat.py:724(<listcomp>)
#         3    0.000    0.000    0.000    0.000 concat.py:73(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:751(<listcomp>)
#         2    0.000    0.000    0.000    0.000 concat.py:770(_maybe_check_integrity)
#         2    0.000    0.000    0.000    0.000 concat.py:777(_concat_indexes)
#         1    0.000    0.000    0.003    0.003 concat.py:94(concatenate_managers)
#        34    0.000    0.000    0.000    0.000 config.py:127(_get_single_key)
#        34    0.000    0.000    0.001    0.000 config.py:145(_get_option)
#        34    0.000    0.000    0.000    0.000 config.py:617(_select_options)
#        34    0.000    0.000    0.000    0.000 config.py:635(_get_root)
#        34    0.000    0.000    0.000    0.000 config.py:649(_get_deprecated_option)
#        34    0.000    0.000    0.000    0.000 config.py:676(_translate_key)
#         1    0.000    0.000    0.106    0.106 construction.py:1006(convert_object_array)
#        21    0.103    0.005    0.106    0.005 construction.py:1028(convert)
#         1    0.000    0.000    0.106    0.106 construction.py:1070(<listcomp>)
#         4    0.000    0.000    0.000    0.000 construction.py:196(mgr_to_mgr)
#        80    0.000    0.000    0.000    0.000 construction.py:416(extract_array)
#         3    0.000    0.000    0.187    0.062 construction.py:423(dict_to_mgr)
#         3    0.000    0.000    0.000    0.000 construction.py:481(<listcomp>)
#        56    0.000    0.000    0.000    0.000 construction.py:481(ensure_wrapped_if_datetimelike)
#         2    0.000    0.000    0.000    0.000 construction.py:487(<listcomp>)
#         1    0.000    0.000    0.489    0.489 construction.py:506(nested_data_to_arrays)
#        63    0.002    0.000    0.007    0.000 construction.py:517(sanitize_array)
#         1    0.000    0.000    0.000    0.000 construction.py:532(treat_as_nested)
#         4    0.000    0.000    0.004    0.001 construction.py:596(_homogenize)
#         1    0.000    0.000    0.000    0.000 construction.py:638(_extract_index)
#         4    0.000    0.000    0.000    0.000 construction.py:688(_sanitize_non_ordered)
#        54    0.000    0.000    0.000    0.000 construction.py:696(_sanitize_ndim)
#        52    0.000    0.000    0.000    0.000 construction.py:735(_sanitize_str_dtypes)
#        54    0.000    0.000    0.000    0.000 construction.py:758(_maybe_repeat)
#         8    0.000    0.000    0.000    0.000 construction.py:769(_try_cast)
#         1    0.002    0.002    0.489    0.489 construction.py:793(to_arrays)
#         1    0.184    0.184    0.382    0.382 construction.py:891(_list_of_dict_to_arrays)
#    117408    0.138    0.000    0.144    0.000 construction.py:915(<genexpr>)
#         2    0.000    0.000    0.000    0.000 construction.py:916(<genexpr>)
#         1    0.053    0.053    0.053    0.053 construction.py:922(<listcomp>)
#         1    0.000    0.000    0.106    0.106 construction.py:928(_finalize_columns_and_data)
#         1    0.000    0.000    0.000    0.000 construction.py:950(_validate_or_indexify_columns)
#         4    0.047    0.012    0.297    0.074 construction.py:96(arrays_to_mgr)
#         3    0.000    0.000    0.000    0.000 contextlib.py:102(__init__)
#         3    0.000    0.000    0.000    0.000 contextlib.py:130(__enter__)
#         3    0.000    0.000    0.000    0.000 contextlib.py:139(__exit__)
#         3    0.000    0.000    0.000    0.000 contextlib.py:279(helper)
#         1    0.000    0.000    0.000    0.000 coroutines.py:164(iscoroutinefunction)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:1210(is_dataclass)
#         6    0.000    0.000    0.000    0.000 datetimelike.py:2043(freq)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:2063(_maybe_pin_freq)
#         3    0.000    0.000    0.000    0.000 datetimelike.py:2148(_creso)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:2152(unit)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:2353(copy)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:2425(ensure_arraylike_for_datetimelike)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:2537(dtype_to_unit)
#         3    0.000    0.000    0.000    0.000 datetimelike.py:319(asi8)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:373(__getitem__)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:390(_get_getitem_freq)
#         4    0.000    0.000    0.000    0.000 datetimes.py:103(tz_to_dtype)
#         1    0.011    0.011    0.011    0.011 datetimes.py:1436(date)
#         9    0.001    0.000    0.005    0.001 datetimes.py:149(should_cache)
#         9    0.000    0.000    0.008    0.001 datetimes.py:209(_maybe_cache)
#         2    0.000    0.000    0.000    0.000 datetimes.py:2184(_sequence_to_dt64)
#         1    0.000    0.000    0.000    0.000 datetimes.py:2310(_construct_from_dt64_naive)
#         2    0.000    0.000    0.000    0.000 datetimes.py:2428(maybe_convert_dtype)
#         1    0.000    0.000    0.000    0.000 datetimes.py:2484(_maybe_infer_tz)
#         2    0.000    0.000    0.000    0.000 datetimes.py:2514(_validate_dt64_dtype)
#         4    0.000    0.000    0.000    0.000 datetimes.py:2570(_validate_tz_from_dtype)
#         1    0.000    0.000    0.000    0.000 datetimes.py:281(tz_convert)
#         1    0.000    0.000    0.000    0.000 datetimes.py:286(tz_localize)
#         4    0.000    0.000    0.000    0.000 datetimes.py:304(_simple_new)
#         9    0.000    0.000    0.160    0.018 datetimes.py:314(_convert_listlike_datetimes)
#         2    0.000    0.000    0.001    0.000 datetimes.py:320(__new__)
#         2    0.000    0.000    0.000    0.000 datetimes.py:329(_from_sequence_not_strict)
#         8    0.146    0.018    0.159    0.020 datetimes.py:482(_to_datetime_with_unit)
#        34    0.000    0.000    0.000    0.000 datetimes.py:551(dtype)
#         6    0.000    0.000    0.000    0.000 datetimes.py:576(tz)
#       501    0.004    0.000    0.004    0.000 datetimes.py:645(__iter__)
#         9    0.000    0.000    0.169    0.019 datetimes.py:673(to_datetime)
#         1    0.000    0.000    0.000    0.000 datetimes.py:835(_local_timestamps)
#         1    0.000    0.000    0.000    0.000 datetimes.py:847(tz_convert)
#         1    0.000    0.000    0.000    0.000 datetimes.py:923(tz_localize)
#         3    0.000    0.000    0.000    0.000 dispatch.py:17(should_extension_dispatch)
#        66    0.000    0.000    0.000    0.000 dtypes.py:1054(construct_from_string)
#         4    0.000    0.000    0.000    0.000 dtypes.py:130(__repr__)
#        66    0.000    0.000    0.000    0.000 dtypes.py:1305(construct_from_string)
#         1    0.000    0.000    0.000    0.000 dtypes.py:1454(__init__)
#        66    0.000    0.000    0.000    0.000 dtypes.py:1835(construct_from_string)
#        66    0.000    0.000    0.000    0.000 dtypes.py:2228(construct_from_string)
#        66    0.000    0.000    0.000    0.000 dtypes.py:342(construct_from_string)
#         3    0.000    0.000    0.000    0.000 dtypes.py:751(__init__)
#         3    0.000    0.000    0.000    0.000 dtypes.py:783(_creso)
#        15    0.000    0.000    0.000    0.000 dtypes.py:790(unit)
#        16    0.000    0.000    0.000    0.000 dtypes.py:804(tz)
#        66    0.000    0.000    0.000    0.000 dtypes.py:831(construct_from_string)
#        11    0.000    0.000    0.000    0.000 dtypes.py:867(__str__)
#         7    0.000    0.000    0.000    0.000 dtypes.py:870(name)
#        18    0.000    0.000    0.000    0.000 dtypes.py:880(__eq__)
#        12    0.000    0.000    0.000    0.000 enum.py:359(__call__)
#        12    0.000    0.000    0.000    0.000 enum.py:678(__new__)
#        12    0.000    0.000    0.000    0.000 enum.py:801(value)
#         6    0.000    0.000    0.000    0.000 enum.py:986(__and__)
#         1    0.000    0.000    0.000    0.000 expressions.py:226(evaluate)
#         1    0.000    0.000    0.000    0.000 expressions.py:67(_evaluate_standard)
#         2    0.000    0.000    0.011    0.006 extension.py:67(fget)
#        91    0.000    0.000    0.000    0.000 flags.py:51(__init__)
#        72    0.000    0.000    0.000    0.000 flags.py:55(allows_duplicate_labels)
#        70    0.000    0.000    0.000    0.000 flags.py:87(allows_duplicate_labels)
#         7    0.000    0.000    0.000    0.000 frame.py:1030(axes)
#         1    0.000    0.000    0.000    0.000 frame.py:1047(shape)
#         1    0.000    0.000    0.001    0.001 frame.py:12675(_reindex_for_setitem)
#        44    0.000    0.000    0.005    0.000 frame.py:1496(items)
#         1    0.000    0.000    0.000    0.000 frame.py:1643(__len__)
#        47    0.000    0.000    0.004    0.000 frame.py:3983(_ixs)
#         6    0.000    0.000    0.003    0.000 frame.py:4062(__getitem__)
#         1    0.000    0.000    0.007    0.007 frame.py:4271(__setitem__)
#         1    0.000    0.000    0.006    0.006 frame.py:4481(_set_item_mgr)
#         1    0.000    0.000    0.007    0.007 frame.py:4514(_set_item)
#         1    0.000    0.000    0.000    0.000 frame.py:4585(_ensure_valid_index)
#        47    0.000    0.000    0.002    0.000 frame.py:4608(_box_col_values)
#         2    0.000    0.000    0.000    0.000 frame.py:4623(_clear_item_cache)
#        47    0.000    0.000    0.005    0.000 frame.py:4626(_get_item_cache)
#         1    0.000    0.000    0.001    0.001 frame.py:5242(_sanitize_column)
#         1    0.000    0.000    0.000    0.000 frame.py:655(_constructor)
#         2    0.000    0.000    0.000    0.000 frame.py:659(_constructor_from_mgr)
#        47    0.000    0.000    0.001    0.000 frame.py:678(_constructor_sliced_from_mgr)
#         4    0.000    0.000    0.788    0.197 frame.py:694(__init__)
#         2    0.000    0.000    0.001    0.001 frame.py:9041(groupby)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:1021(_argsort_dispatcher)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:1025(argsort)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1764(_ravel_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1768(ravel)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1877(_nonzero_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1881(nonzero)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2172(_sum_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2177(sum)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2416(_all_dispatcher)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2421(all)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2974(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2979(prod)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:53(_wrapfunc)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:71(_wrapreduction)
#         4    0.000    0.000    0.000    0.000 fromnumeric.py:72(<dictcomp>)
#        27    0.000    0.000    0.000    0.000 frozen.py:76(__getitem__)
#        10    0.000    0.000    0.000    0.000 function.py:104(process_skipna)
#        10    0.000    0.000    0.000    0.000 function.py:124(validate_argmax_with_skipna)
#        10    0.000    0.000    0.000    0.000 function.py:383(validate_minmax_axis)
#        13    0.000    0.000    0.000    0.000 function.py:64(__call__)
#         1    0.000    0.000    0.000    0.000 function_base.py:5169(_delete_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:5173(delete)
#         1    0.000    0.000    0.000    0.000 function_base.py:5365(_insert_dispatcher)
#         1    0.000    0.000    0.000    0.000 function_base.py:5369(insert)
#         2    0.000    0.000    0.000    0.000 function_base.py:5559(_append_dispatcher)
#         2    0.000    0.000    0.000    0.000 function_base.py:5563(append)
#         1    0.000    0.000    0.000    0.000 functools.py:421(_unwrap_partial)
#         3    0.000    0.000    0.000    0.000 generic.py:1826(_check_label_or_level_ambiguity)
#         3    0.000    0.000    0.000    0.000 generic.py:1847(<genexpr>)
#         3    0.000    0.000    0.000    0.000 generic.py:2077(__contains__)
#         1    0.000    0.000    0.001    0.001 generic.py:2167(__array_ufunc__)
#        91    0.000    0.000    0.001    0.000 generic.py:278(__init__)
#        55    0.000    0.000    0.000    0.000 generic.py:339(_from_mgr)
#        70    0.000    0.000    0.000    0.000 generic.py:363(attrs)
#       490    0.000    0.000    0.001    0.000 generic.py:37(_check)
#         2    0.000    0.000    0.001    0.001 generic.py:4027(take)
#       142    0.000    0.000    0.000    0.000 generic.py:405(flags)
#         2    0.000    0.000    0.001    0.001 generic.py:4142(_take_with_is_copy)
#       490    0.001    0.000    0.001    0.000 generic.py:42(_instancecheck)
#         1    0.000    0.000    0.000    0.000 generic.py:4379(_set_is_copy)
#         1    0.000    0.000    0.000    0.000 generic.py:4402(_check_setitem_copy)
#         1    0.000    0.000    0.001    0.001 generic.py:4757(drop)
#         1    0.000    0.000    0.001    0.001 generic.py:4796(_drop_axis)
#        17    0.000    0.000    0.001    0.000 generic.py:511(_validate_dtype)
#        35    0.000    0.000    0.000    0.000 generic.py:572(_get_axis_number)
#         1    0.000    0.000    0.000    0.000 generic.py:580(_get_axis_name)
#        10    0.000    0.000    0.000    0.000 generic.py:586(_get_axis)
#         4    0.000    0.000    0.000    0.000 generic.py:592(_get_block_manager_axis)
#        70    0.001    0.000    0.001    0.000 generic.py:6236(__finalize__)
#         4    0.000    0.000    0.000    0.000 generic.py:6270(<genexpr>)
#         6    0.000    0.000    0.000    0.000 generic.py:6277(<genexpr>)
#        32    0.000    0.000    0.000    0.000 generic.py:6284(__getattr__)
#       237    0.001    0.000    0.002    0.000 generic.py:6301(__setattr__)
#        32    0.000    0.000    0.014    0.000 generic.py:6463(astype)
#         1    0.000    0.000    0.000    0.000 generic.py:6662(copy)
#         5    0.000    0.000    0.000    0.000 generic.py:667(_info_axis)
#        10    0.000    0.000    0.000    0.000 generic.py:696(ndim)
#        34    0.000    0.000    0.001    0.000 generic.py:807(_set_axis)
#       371    0.000    0.000    0.012    0.000 genericpath.py:16(exists)
#        21    0.000    0.000    0.000    0.000 getlimits.py:685(__init__)
#        21    0.000    0.000    0.000    0.000 getlimits.py:696(min)
#        21    0.000    0.000    0.000    0.000 getlimits.py:709(max)
#         2    0.000    0.000    0.001    0.001 groupby.py:1296(__init__)
#         5    0.000    0.000    0.000    0.000 groupby.py:1340(<genexpr>)
#         2    0.000    0.000    0.000    0.000 groupby.py:2142(_obj_1d_constructor)
#         2    0.000    0.000    0.106    0.053 groupby.py:2985(size)
#         2    0.000    0.000    0.000    0.000 groupby.py:5565(_reindex_output)
#         3    0.000    0.000    0.000    0.000 groupby.py:5607(<genexpr>)
#         3    0.000    0.000    0.000    0.000 grouper.py:1080(_is_label_like)
#         3    0.000    0.000    0.000    0.000 grouper.py:1084(_convert_grouper)
#         3    0.000    0.000    0.000    0.000 grouper.py:527(__init__)
#         3    0.000    0.000    0.000    0.000 grouper.py:638(_passed_categorical)
#         3    0.000    0.000    0.000    0.000 grouper.py:643(name)
#         3    0.000    0.000    0.000    0.000 grouper.py:661(_ilevel)
#         4    0.000    0.000    0.001    0.000 grouper.py:676(ngroups)
#         5    0.000    0.000    0.095    0.019 grouper.py:689(codes)
#         3    0.000    0.000    0.000    0.000 grouper.py:722(_result_index)
#         3    0.000    0.000    0.001    0.000 grouper.py:744(_group_index)
#         3    0.000    0.000    0.095    0.032 grouper.py:777(_codes_and_uniques)
#         2    0.000    0.000    0.001    0.001 grouper.py:846(get_grouper)
#         5    0.000    0.000    0.000    0.000 grouper.py:947(<genexpr>)
#         5    0.000    0.000    0.000    0.000 grouper.py:948(<genexpr>)
#         5    0.000    0.000    0.000    0.000 grouper.py:949(<genexpr>)
#         3    0.000    0.000    0.000    0.000 grouper.py:983(is_in_axis)
#         3    0.000    0.000    0.000    0.000 grouper.py:999(is_in_obj)
#         2    0.000    0.000    0.000    0.000 indexing.py:1165(_check_deprecated_callable_usage)
#         2    0.000    0.000    0.000    0.000 indexing.py:1176(__getitem__)
#         2    0.000    0.000    0.000    0.000 indexing.py:161(iloc)
#         1    0.000    0.000    0.000    0.000 indexing.py:1696(_get_list_axis)
#         2    0.000    0.000    0.000    0.000 indexing.py:1719(_getitem_axis)
#         1    0.000    0.000    0.000    0.000 indexing.py:1756(_get_slice_axis)
#         1    0.000    0.000    0.000    0.000 indexing.py:2752(need_slice)
#        18    0.000    0.000    0.000    0.000 indexing.py:2765(check_dict_or_set_indexers)
#         3    0.000    0.000    0.000    0.000 inference.py:105(is_file_like)
#        13    0.000    0.000    0.000    0.000 inference.py:195(is_array_like)
#        35    0.000    0.000    0.000    0.000 inference.py:273(is_dict_like)
#       106    0.000    0.000    0.000    0.000 inference.py:300(<genexpr>)
#         1    0.000    0.000    0.000    0.000 inference.py:306(is_named_tuple)
#       168    0.000    0.000    0.000    0.000 inference.py:334(is_hashable)
#         1    0.000    0.000    0.000    0.000 inference.py:404(is_dataclass)
#         1    0.000    0.000    0.000    0.000 inspect.py:1049(__init__)
#       177    0.000    0.000    0.000    0.000 inspect.py:1058(tokeneater)
#         1    0.000    0.000    0.001    0.001 inspect.py:1101(getblock)
#         1    0.000    0.000    0.077    0.077 inspect.py:1112(getsourcelines)
#      1890    0.001    0.000    0.001    0.000 inspect.py:182(ismodule)
#        34    0.000    0.000    0.000    0.000 inspect.py:191(isclass)
#         3    0.000    0.000    0.000    0.000 inspect.py:199(ismethod)
#         3    0.000    0.000    0.000    0.000 inspect.py:277(isfunction)
#         1    0.000    0.000    0.000    0.000 inspect.py:290(_has_code_flag)
#         1    0.000    0.000    0.000    0.000 inspect.py:308(iscoroutinefunction)
#         3    0.000    0.000    0.000    0.000 inspect.py:355(istraceback)
#         3    0.000    0.000    0.000    0.000 inspect.py:365(isframe)
#        12    0.000    0.000    0.000    0.000 inspect.py:379(iscode)
#         1    0.000    0.000    0.000    0.000 inspect.py:612(unwrap)
#         1    0.000    0.000    0.000    0.000 inspect.py:629(_is_wrapper)
#       483    0.000    0.000    0.001    0.000 inspect.py:773(getfile)
#       426    0.001    0.000    0.015    0.000 inspect.py:813(getsourcefile)
#      1278    0.000    0.000    0.000    0.000 inspect.py:820(<genexpr>)
#      1222    0.000    0.000    0.000    0.000 inspect.py:823(<genexpr>)
#       426    0.001    0.000    0.021    0.000 inspect.py:838(getabsfile)
#         1    0.002    0.002    0.076    0.076 inspect.py:850(getmodule)
#         1    0.000    0.000    0.076    0.076 inspect.py:932(findsource)
#         1    0.000    0.000    0.000    0.000 iostream.py:125(_event_pipe)
#         1    0.000    0.000    0.000    0.000 iostream.py:241(schedule)
#        27    0.000    0.000    0.000    0.000 iostream.py:503(_is_master_process)
#        27    0.000    0.000    0.000    0.000 iostream.py:530(_schedule_flush)
#        27    0.000    0.000    0.001    0.000 iostream.py:608(write)
# ...
#         1    0.000    0.000    0.000    0.000 sorting.py:170(<listcomp>)
#         2    0.000    0.000    0.000    0.000 sorting.py:238(is_int64_overflow_possible)
#         1    0.001    0.001    0.001    0.001 sorting.py:246(_decons_group_index)
#         1    0.000    0.000    0.001    0.001 sorting.py:268(decons_obs_group_ids)
#         1    0.003    0.003    0.006    0.006 sorting.py:687(compress_group_index)
#         1    0.000    0.000    0.003    0.003 sorting.py:718(_reorder_by_uniques)
#        25    0.000    0.000    0.000    0.000 sre_compile.py:265(_compile_charset)
#        25    0.001    0.000    0.001    0.000 sre_compile.py:292(_optimize_charset)
#         7    0.000    0.000    0.000    0.000 sre_compile.py:447(_simple)
#        15    0.000    0.000    0.000    0.000 sre_compile.py:477(_get_iscased)
#       9/6    0.000    0.000    0.000    0.000 sre_compile.py:485(_get_literal_prefix)
#         6    0.000    0.000    0.000    0.000 sre_compile.py:516(_get_charset_prefix)
#         6    0.000    0.000    0.001    0.000 sre_compile.py:560(_compile_info)
#        12    0.000    0.000    0.000    0.000 sre_compile.py:619(isstring)
#         6    0.000    0.000    0.007    0.001 sre_compile.py:622(_code)
#         6    0.000    0.000    0.021    0.003 sre_compile.py:783(compile)
#        17    0.000    0.000    0.000    0.000 sre_compile.py:81(_combine_flags)
#      56/6    0.005    0.000    0.006    0.001 sre_compile.py:87(_compile)
#        58    0.000    0.000    0.000    0.000 sre_parse.py:112(__init__)
#        86    0.000    0.000    0.000    0.000 sre_parse.py:161(__len__)
#       488    0.000    0.000    0.000    0.000 sre_parse.py:165(__getitem__)
#         7    0.000    0.000    0.000    0.000 sre_parse.py:169(__setitem__)
#       259    0.000    0.000    0.000    0.000 sre_parse.py:173(append)
#     67/18    0.001    0.000    0.001    0.000 sre_parse.py:175(getwidth)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:225(__init__)
#       352    0.001    0.000    0.001    0.000 sre_parse.py:234(__next)
#        89    0.000    0.000    0.000    0.000 sre_parse.py:250(match)
#       278    0.000    0.000    0.001    0.000 sre_parse.py:255(get)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:268(getuntil)
#        40    0.000    0.000    0.000    0.000 sre_parse.py:287(tell)
#        21    0.000    0.000    0.000    0.000 sre_parse.py:356(_escape)
#         4    0.000    0.000    0.000    0.000 sre_parse.py:433(_uniq)
#      18/6    0.000    0.000    0.013    0.002 sre_parse.py:436(_parse_sub)
#      46/9    0.010    0.000    0.013    0.001 sre_parse.py:494(_parse)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:76(__init__)
#        35    0.000    0.000    0.000    0.000 sre_parse.py:82(groups)
#        11    0.000    0.000    0.000    0.000 sre_parse.py:85(opengroup)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:928(fix_flags)
#         6    0.000    0.000    0.013    0.002 sre_parse.py:944(parse)
#        11    0.000    0.000    0.001    0.000 sre_parse.py:97(closegroup)
#        66    0.000    0.000    0.000    0.000 string_.py:140(construct_from_string)
#         8    0.001    0.000    0.002    0.000 take.py:120(_take_nd_ndarray)
#         2    0.000    0.000    0.000    0.000 take.py:287(_get_take_nd_function_cached)
#         8    0.000    0.000    0.000    0.000 take.py:325(_get_take_nd_function)
#         8    0.000    0.000    0.000    0.000 take.py:564(_take_preprocess_indexer_and_fill_value)
#         8    0.000    0.000    0.002    0.000 take.py:59(take_nd)
#         1    0.000    0.000    0.000    0.000 threading.py:1102(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1169(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:553(is_set)
#         1    0.000    0.000    0.000    0.000 tokenize.py:297(detect_encoding)
#         1    0.000    0.000    0.000    0.000 tokenize.py:321(read_or_stop)
#         1    0.000    0.000    0.000    0.000 tokenize.py:327(find_cookie)
#         1    0.000    0.000    0.000    0.000 tokenize.py:390(open)
#       178    0.000    0.000    0.001    0.000 tokenize.py:431(_tokenize)
#         1    0.000    0.000    0.000    0.000 tokenize.py:614(generate_tokens)
#        12    0.000    0.000    0.000    0.000 types.py:176(__get__)
#       160    0.000    0.000    0.000    0.000 typing.py:1737(cast)
#         2    0.000    0.000    0.000    0.000 utils.py:239(maybe_convert_indices)
#         1    0.000    0.000    0.000    0.000 utils.py:62(is_list_like_indexer)
#        12    0.000    0.000    0.009    0.001 warnings.py:130(filterwarnings)
#        53    0.000    0.000    0.000    0.000 warnings.py:165(simplefilter)
#        65    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#        74    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#        74    0.001    0.000    0.001    0.000 warnings.py:458(__enter__)
#        74    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#       340    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FF8D7F5C920}
#       155    0.000    0.000    0.001    0.000 {built-in method _abc._abc_instancecheck}
#    134/18    0.000    0.000    0.001    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup_error}
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup}
#         4    0.096    0.024    0.096    0.024 {built-in method _codecs.utf_8_decode}
#         8    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#         8    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         3    0.000    0.000    0.000    0.000 {built-in method _locale.setlocale}
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.gt}
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.or_}
#         6    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#       198    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_iscased}
#       173    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_tolower}
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#       213    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#      1276    0.001    0.000    0.001    0.000 {built-in method _winapi.LCMapStringEx}
#        80    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#       877    0.001    0.000    0.001    0.000 {built-in method builtins.any}
#        61    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    6.920    6.920 {built-in method builtins.exec}
# 1320/1316    0.000    0.000    0.011    0.000 {built-in method builtins.getattr}
#      1632    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#       177    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.id}
# 130578/130428    0.007    0.000    0.009    0.000 {built-in method builtins.isinstance}
#       496    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 13668/13243    0.001    0.000    0.002    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        33    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       151    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#       219    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         4    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         2    0.000    0.000    0.000    0.000 {built-in method io.open}
#       850    0.043    0.000    0.043    0.000 {built-in method nt._getfinalpathname}
#       426    0.001    0.000    0.001    0.000 {built-in method nt._getfullpathname}
#      3833    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#       426    0.000    0.000    0.000    0.000 {built-in method nt.getcwd}
#        27    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#       382    0.012    0.000    0.012    0.000 {built-in method nt.stat}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#        43    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#        22    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#   120/119    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.datetime_data}
#       116    0.013    0.000    0.013    0.000 {built-in method numpy.empty}
#         1    3.914    3.914    3.914    3.914 {built-in method pandas._libs.json.ujson_loads}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getrefcount}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.gettrace}
#         2    0.000    0.000    0.000    0.000 {built-in method sys.settrace}
#        27    0.000    0.000    0.000    0.000 {function FrozenList.__getitem__ at 0x000002117EB7A290}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#        27    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         5    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         8    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        42    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#        17    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#      1520    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        10    0.000    0.000    0.000    0.000 {method 'argmax' of 'numpy.ndarray' objects}
#        14    0.049    0.004    0.049    0.004 {method 'argsort' of 'numpy.ndarray' objects}
#        55    0.003    0.000    0.003    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        35    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         7    0.003    0.000    0.003    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#      1896    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        33    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#        89    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#    118870    0.023    0.000    0.023    0.000 {method 'get' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#        67    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#       140    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#        15    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#       902    0.106    0.000    0.106    0.000 {method 'join' of 'str' objects}
#    117410    0.006    0.000    0.006    0.000 {method 'keys' of 'dict' objects}
#       103    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#       851    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#       229    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        31    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'put' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'read' of '_io.StringIO' objects}
#         1    0.328    0.328    0.423    0.423 {method 'read' of '_io.TextIOWrapper' objects}
#         1    0.000    0.000    0.000    0.000 {method 'readline' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'readlines' of '_io._IOBase' objects}
#        65    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        65    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#      3840    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        11    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#       156    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#        66    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#        20    0.000    0.000    0.000    0.000 {method 'searchsorted' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#       155    0.000    0.000    0.000    0.000 {method 'span' of 're.Match' objects}
#       886    0.279    0.000    0.279    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#      3666    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#    117408    0.185    0.000    0.185    0.000 {method 'strip' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#        18    0.003    0.000    0.003    0.000 {method 'take' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        19    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        27    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#        27    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
cProfile.run('q1_memory(file_path=file_path)')
# Out:
# Filename: c:\Users\sestupinan\Documents\latam\latam-challenge-sestupinan\src\q1_memory.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#      9    134.7 MiB    134.7 MiB           1   @profile
#     10                                         def q1_memory(file_path: str) -> List[Tuple[datetime.date, str]]:
#     11                                             # Dictionaries to store the information
#     12    134.7 MiB      0.0 MiB           1       date_list = defaultdict(int) # Dict with number of posts on that day
#     13    134.7 MiB      0.0 MiB           1       user_date_list = defaultdict(int) # Dict with number of posts per user on that day
#     14
#     15                                             # Date format to use
#     16    134.7 MiB      0.0 MiB           1       format = '%Y-%m-%d'
#     17    139.3 MiB     -0.1 MiB           2       with open(file_path) as f:
#     18    139.4 MiB  -1843.5 MiB      117408           for jsonObj in f:
#     19                                                     # To optimize memory, we are only storing in permanent variables the two fields we need (date and username)
#     20    139.4 MiB  -1843.7 MiB      117407               tweetDict = json.loads(jsonObj)
#     21    139.4 MiB  -1844.2 MiB      117407               formatted_date = datetime.strptime(tweetDict['date'].split('T')[0], format).date()
#     22    139.4 MiB  -1844.2 MiB      117407               username = tweetDict['user']['username']
#     23    139.4 MiB  -1844.2 MiB      117407               date_list[formatted_date] +=1
#     24    139.4 MiB  -1840.7 MiB      117407               user_date_list[(formatted_date, username)]+=1
#     25
#     26                                             # Sorts the dictionary by values in descending order
#     27    139.3 MiB      0.0 MiB          27       date_list = sorted(date_list.items(), key=lambda x: x[1], reverse=True)
#     28
#     29                                             # Extracts the top 10 dates
#     30    139.3 MiB      0.0 MiB           1       date_list = date_list[:10]
#     31
#     32    139.3 MiB      0.0 MiB           1       listed = []
#     33
#     34                                             # Computes top user per day
#     35    139.3 MiB      0.0 MiB          11       for date, n in date_list:
#     36    139.3 MiB      0.0 MiB          10           max_tweets = 0
#     37    139.3 MiB      0.0 MiB          10           max_user = ''
#     38    139.3 MiB      0.0 MiB      516470           for (tweet_date, username), count in user_date_list.items():
#     39    139.3 MiB      0.0 MiB      516460               if tweet_date == date and count > max_tweets:
#     40    139.3 MiB      0.0 MiB          59                   max_tweets = count
#     41    139.3 MiB      0.0 MiB          59                   max_user = username
#     42    139.3 MiB      0.0 MiB          10           listed.append((date, max_user))
#     43    139.3 MiB      0.0 MiB           1       return listed
#
#
#          4329655 function calls (4329607 primitive calls) in 59.678 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       253    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000   59.678   59.678 <string>:1(<module>)
#    117407    0.597    0.000    3.882    0.000 __init__.py:299(loads)
#         1    0.000    0.000    0.000    0.000 _strptime.py:238(pattern)
#    117407    0.185    0.000    2.405    0.000 _strptime.py:26(_getlang)
#         1    0.000    0.000    0.005    0.005 _strptime.py:261(compile)
#    117407   18.668    0.000   21.390    0.000 _strptime.py:309(_strptime)
#    117407    1.133    0.000   22.523    0.000 _strptime.py:565(_strptime_datetime)
#         2    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#         2    0.000    0.000    0.000    0.000 codecs.py:319(decode)
#         1    0.000    0.000    0.000    0.000 contextlib.py:102(__init__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:130(__enter__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:139(__exit__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:279(helper)
#         1    0.000    0.000    0.000    0.000 coroutines.py:164(iscoroutinefunction)
#     49772    0.084    0.000    0.836    0.000 cp1252.py:22(decode)
#    117407    0.538    0.000    3.241    0.000 decoder.py:332(decode)
#    117407    2.554    0.000    2.554    0.000 decoder.py:343(raw_decode)
#         2    0.000    0.000    0.000    0.000 enum.py:359(__call__)
#         2    0.000    0.000    0.000    0.000 enum.py:678(__new__)
#         1    0.000    0.000    0.000    0.000 enum.py:801(value)
#         1    0.000    0.000    0.000    0.000 enum.py:986(__and__)
#         1    0.000    0.000    0.000    0.000 functools.py:421(_unwrap_partial)
#         2    0.000    0.000    0.000    0.000 genericpath.py:16(exists)
#         1    0.000    0.000    0.000    0.000 inspect.py:1049(__init__)
#       253    0.000    0.000    0.000    0.000 inspect.py:1058(tokeneater)
#         1    0.000    0.000    0.001    0.001 inspect.py:1101(getblock)
#         1    0.000    0.000    0.002    0.002 inspect.py:1112(getsourcelines)
#         4    0.000    0.000    0.000    0.000 inspect.py:182(ismodule)
#         2    0.000    0.000    0.000    0.000 inspect.py:191(isclass)
#         3    0.000    0.000    0.000    0.000 inspect.py:199(ismethod)
#         3    0.000    0.000    0.000    0.000 inspect.py:277(isfunction)
#         1    0.000    0.000    0.000    0.000 inspect.py:290(_has_code_flag)
#         1    0.000    0.000    0.000    0.000 inspect.py:308(iscoroutinefunction)
#         3    0.000    0.000    0.000    0.000 inspect.py:355(istraceback)
#         3    0.000    0.000    0.000    0.000 inspect.py:365(isframe)
#        18    0.000    0.000    0.000    0.000 inspect.py:379(iscode)
#         1    0.000    0.000    0.000    0.000 inspect.py:612(unwrap)
#         1    0.000    0.000    0.000    0.000 inspect.py:629(_is_wrapper)
#         1    0.000    0.000    0.000    0.000 inspect.py:773(getfile)
#         1    0.000    0.000    0.000    0.000 inspect.py:813(getsourcefile)
#         3    0.000    0.000    0.000    0.000 inspect.py:820(<genexpr>)
#         3    0.000    0.000    0.000    0.000 inspect.py:823(<genexpr>)
#         1    0.000    0.000    0.000    0.000 inspect.py:838(getabsfile)
#         1    0.000    0.000    0.000    0.000 inspect.py:850(getmodule)
#         1    0.000    0.000    0.001    0.001 inspect.py:932(findsource)
#         1    0.000    0.000    0.000    0.000 iostream.py:125(_event_pipe)
#         1    0.000    0.000    0.000    0.000 iostream.py:241(schedule)
#        39    0.000    0.000    0.000    0.000 iostream.py:503(_is_master_process)
#        39    0.000    0.000    0.000    0.000 iostream.py:530(_schedule_flush)
#        39    0.000    0.000    0.000    0.000 iostream.py:608(write)
#         2    0.000    0.000    0.000    0.000 linecache.py:36(getlines)
#         1    0.000    0.000    0.000    0.000 linecache.py:52(checkcache)
#         1    0.000    0.000    0.000    0.000 linecache.py:80(updatecache)
#    117407    1.217    0.000    1.258    0.000 locale.py:396(normalize)
#    117407    0.456    0.000    1.714    0.000 locale.py:479(_parse_localename)
#    117407    0.305    0.000    2.220    0.000 locale.py:587(getlocale)
#         1    0.000    0.000   59.678   59.678 memory_profiler.py:1185(wrapper)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:1201(choose_backend)
#         6    0.000    0.000    0.000    0.000 memory_profiler.py:1215(<genexpr>)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:640(__init__)
#       2/1    0.000    0.000    0.002    0.002 memory_profiler.py:645(add)
#         2    0.000    0.000    0.000    0.000 memory_profiler.py:689(items)
#        36    0.000    0.000    0.000    0.000 memory_profiler.py:695(<genexpr>)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:702(__init__)
#         1    0.000    0.000    0.002    0.002 memory_profiler.py:713(__call__)
#         1    0.000    0.000    0.002    0.002 memory_profiler.py:728(add_function)
#         2    0.000    0.000    0.000    0.000 memory_profiler.py:740(_count_ctxmgr)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:748(wrap_function)
#         1    0.002    0.002   59.676   59.676 memory_profiler.py:759(f)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:775(enable_by_count)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:782(disable_by_count)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:842(enable)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:849(disable)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:853(show_results)
#         1    0.000    0.000    0.000    0.000 ntpath.py:150(splitdrive)
#         1    0.000    0.000    0.000    0.000 ntpath.py:489(normpath)
#         1    0.000    0.000    0.000    0.000 ntpath.py:51(normcase)
#         1    0.000    0.000    0.000    0.000 ntpath.py:563(abspath)
#        13    0.001    0.000    0.001    0.000 q1_memory.py:27(<lambda>)
#         1   32.136   32.136   59.674   59.674 q1_memory.py:9(q1_memory)
#         4    0.000    0.000    0.005    0.001 re.py:249(compile)
#         4    0.000    0.000    0.005    0.001 re.py:288(_compile)
#         2    0.000    0.000    0.000    0.000 re.py:324(_subx)
#         1    0.000    0.000    0.000    0.000 socket.py:621(send)
#        14    0.000    0.000    0.000    0.000 sre_compile.py:265(_compile_charset)
#        14    0.001    0.000    0.001    0.000 sre_compile.py:292(_optimize_charset)
#         3    0.000    0.000    0.000    0.000 sre_compile.py:477(_get_iscased)
#       2/1    0.000    0.000    0.000    0.000 sre_compile.py:485(_get_literal_prefix)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:516(_get_charset_prefix)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:560(_compile_info)
#         2    0.000    0.000    0.000    0.000 sre_compile.py:619(isstring)
#         1    0.000    0.000    0.002    0.002 sre_compile.py:622(_code)
#         1    0.000    0.000    0.005    0.005 sre_compile.py:783(compile)
#         5    0.000    0.000    0.000    0.000 sre_compile.py:81(_combine_flags)
#      12/1    0.001    0.000    0.002    0.002 sre_compile.py:87(_compile)
#        12    0.000    0.000    0.000    0.000 sre_parse.py:112(__init__)
#        16    0.000    0.000    0.000    0.000 sre_parse.py:161(__len__)
#        58    0.000    0.000    0.000    0.000 sre_parse.py:165(__getitem__)
#        25    0.000    0.000    0.000    0.000 sre_parse.py:173(append)
#      15/4    0.000    0.000    0.000    0.000 sre_parse.py:175(getwidth)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:225(__init__)
#        80    0.000    0.000    0.000    0.000 sre_parse.py:234(__next)
#        35    0.000    0.000    0.000    0.000 sre_parse.py:250(match)
#        50    0.000    0.000    0.000    0.000 sre_parse.py:255(get)
#         3    0.000    0.000    0.000    0.000 sre_parse.py:268(getuntil)
#        15    0.000    0.000    0.000    0.000 sre_parse.py:287(tell)
#         5    0.000    0.000    0.000    0.000 sre_parse.py:356(_escape)
#         8    0.000    0.000    0.000    0.000 sre_parse.py:433(_uniq)
#       4/1    0.000    0.000    0.003    0.003 sre_parse.py:436(_parse_sub)
#      10/1    0.002    0.000    0.003    0.003 sre_parse.py:494(_parse)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:76(__init__)
#         8    0.000    0.000    0.000    0.000 sre_parse.py:82(groups)
#         3    0.000    0.000    0.000    0.000 sre_parse.py:85(opengroup)
#         1    0.000    0.000    0.000    0.000 sre_parse.py:928(fix_flags)
#         1    0.000    0.000    0.003    0.003 sre_parse.py:944(parse)
#         3    0.000    0.000    0.000    0.000 sre_parse.py:97(closegroup)
#         1    0.000    0.000    0.000    0.000 threading.py:1102(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1169(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:553(is_set)
#         1    0.000    0.000    0.000    0.000 tokenize.py:297(detect_encoding)
#         1    0.000    0.000    0.000    0.000 tokenize.py:321(read_or_stop)
#         1    0.000    0.000    0.000    0.000 tokenize.py:327(find_cookie)
#         1    0.000    0.000    0.000    0.000 tokenize.py:390(open)
#       254    0.001    0.000    0.001    0.000 tokenize.py:431(_tokenize)
#         1    0.000    0.000    0.000    0.000 tokenize.py:614(generate_tokens)
#         1    0.000    0.000    0.000    0.000 types.py:176(__get__)
#       253    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FF8D7F5C920}
#     49772    0.752    0.000    0.752    0.000 {built-in method _codecs.charmap_decode}
#         2    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#    117407    0.202    0.000    0.202    0.000 {built-in method _locale.setlocale}
#         1    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#         7    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_iscased}
#         1    0.000    0.000    0.000    0.000 {built-in method _winapi.LCMapStringEx}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000   59.678   59.678 {built-in method builtins.exec}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#    352368    0.031    0.000    0.031    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 352493/352481    0.042    0.000    0.042    0.000 {built-in method builtins.len}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        33    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        23    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.sorted}
#         8    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         2    0.000    0.000    0.000    0.000 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 {built-in method nt._getfullpathname}
#         3    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#        39    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         3    0.000    0.000    0.000    0.000 {built-in method nt.stat}
#    117407    0.243    0.000   22.766    0.000 {built-in method strptime}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.gettrace}
#         2    0.000    0.000    0.000    0.000 {built-in method sys.settrace}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#        39    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#    117407    0.021    0.000    0.021    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       229    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#    117407    0.016    0.000    0.016    0.000 {method 'date' of 'datetime.datetime' objects}
#         1    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    352221    0.038    0.000    0.038    0.000 {method 'end' of 're.Match' objects}
#         8    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        30    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#        83    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#    352269    0.053    0.000    0.053    0.000 {method 'get' of 'dict' objects}
#    117407    0.057    0.000    0.057    0.000 {method 'groupdict' of 're.Match' objects}
#         3    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#       189    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#        12    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#    117407    0.017    0.000    0.017    0.000 {method 'keys' of 'dict' objects}
#    117407    0.016    0.000    0.016    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#    352448    0.199    0.000    0.199    0.000 {method 'match' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'readline' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'readlines' of '_io._IOBase' objects}
#         3    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#       224    0.000    0.000    0.000    0.000 {method 'span' of 're.Match' objects}
#    117408    0.038    0.000    0.038    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#    117410    0.033    0.000    0.033    0.000 {method 'startswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#    234814    0.025    0.000    0.025    0.000 {method 'toordinal' of 'datetime.date' objects}
#         1    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#    117407    0.014    0.000    0.014    0.000 {method 'weekday' of 'datetime.date' objects}
#        39    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %% [markdown]
# ## 3.1 Challenge 2
# Para el challenge 2, se decidió hacer una aproximación usando dos estructuras de datos distintas para cada uno de los escenarios. Para la optimización de tiempo, se uso la estructura Counter. Es una sublcase del diccionario, y permite acceso a métodos que normalmente no están disponibles en su clase base.
#
# En específico, se usó el método most_common para evitar ordernar la lista con los resultados, evadiendo así dicha operación costosa (este método tiene complejidad O(n log k) que para nuestros valores es mejor que O(n log n), que es la complejidad del metodo sorted() en python).
#
# Para el resto del problema, se recolecta la información a la par que se lee cada línea del archivo de datos, donde se va guardando mediante un regex los emojis encontrados en cada tweet.

# %%
res_2_time = q2_time(file_path)
res_2_time
# Out:
# Filename: c:\Users\sestupinan\Documents\latam\latam-challenge-sestupinan\src\q2_time.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#      8    104.2 MiB    104.2 MiB           1   @profile
#      9                                         def q2_time(file_path: str) -> List[Tuple[str, int]]:
#     10
#     11                                             # Regex pattern for emojis
#     12    104.2 MiB      0.0 MiB           1       emoji_pattern = re.compile(r'[\U0001F300-\U0001F6FF\U0001F900-\U0001F9FF\u2600-\u26FF\u2700-\u27BF]', flags=re.UNICODE)
#     13
#     14    104.2 MiB      0.0 MiB           1       emojis_dict = Counter()
#     15    104.2 MiB      0.0 MiB           2       with open(file_path) as f:
#     16    104.2 MiB      0.0 MiB      117408               for jsonObj in f:
#     17    104.2 MiB      0.0 MiB      117407                   tweetDict = json.loads(jsonObj)
#     18                                                         # Uses the regex previously created to find all the emojis in the tweet content
#     19    104.2 MiB      0.0 MiB      117407                   emojis = emoji_pattern.findall(tweetDict['content'])
#     20    104.2 MiB      0.0 MiB      162711                   for emoji in emojis:
#     21                                                             # Sums 1 to the quantity of appereances of the emoji if it already exists
#     22    104.2 MiB      0.0 MiB       45304                       if emojis_dict.get(emoji) is not None:
#     23    104.2 MiB      0.0 MiB       44691                           emojis_dict[emoji] = emojis_dict[emoji] + 1
#     24                                                             # Adds the emoji to the dictionary and sets the value to 1 if it did not exist
#     25                                                             else:
#     26    104.2 MiB      0.0 MiB         613                           emojis_dict[emoji] = 1
#     27
#     28                                             # Sorts the dictionary by values in descending order
#     29                                             emojis_dict.most_common(10)
# [('🙏', 7286),
#  ('😂', 3072),
#  ('🚜', 2972),
#  ('✊', 2411),
#  ('🌾', 2363),
#  ('🏻', 2080),
#  ('❤', 1779),
#  ('🤣', 1668),
#  ('🏽', 1218),
#  ('👇', 1108)]

# %% [markdown]
# Para la optimización de memoria, se usaron los diccionarios en vez de la estructura counter. De esta forma, al ser una estructura de datos más simple, se ahorra en memoria, en especial cuando el volumen de datos crece más en el procesamiento. Esto provoca que tengamos que ordenar la lista para poder llegar al resultado.

# %%
res_2_mem = q2_memory(file_path)
res_2_mem
# Out:
# Filename: c:\Users\sestupinan\Documents\latam\latam-challenge-sestupinan\src\q2_memory.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#      7    104.2 MiB    104.2 MiB           1   @profile
#      8                                         def q2_memory(file_path: str) -> List[Tuple[str, int]]:
#      9
#     10    104.2 MiB      0.0 MiB           1       # Regex pattern for emojis
#     11                                             emoji_pattern = re.compile(r'[\U0001F300-\U0001F6FF\U0001F900-\U0001F9FF\u2600-\u26FF\u2700-\u27BF]', flags=re.UNICODE)
#     12    104.2 MiB      0.0 MiB           1
#     13    104.2 MiB      0.0 MiB           2       emojis_dict = Counter()
#     14    104.2 MiB      0.0 MiB      117408       with open(file_path) as f:
#     15    104.2 MiB      0.0 MiB      117407               for jsonObj in f:
#     16                                                         tweetDict = json.loads(jsonObj)
#     17    104.2 MiB      0.0 MiB      117407                   # Uses the regex previously created to find all the emojis in the tweet content
#     18    104.2 MiB      0.0 MiB      162711                   emojis = emoji_pattern.findall(tweetDict['content'])
#     19                                                         for emoji in emojis:
#     20    104.2 MiB      0.0 MiB       45304                       # Sums 1 to the quantity of appereances of the emoji if it already exists
#     21    104.2 MiB      0.0 MiB       44691                       if emojis_dict.get(emoji) is not None:
#     22                                                                 emojis_dict[emoji] = emojis_dict[emoji] + 1
#     23                                                             # Adds the emoji to the dictionary and sets the value to 1 if it did not exist
#     24    104.2 MiB      0.0 MiB         613                       else:
#     25                                                                 emojis_dict[emoji] = 1
#     26
#     27    104.2 MiB      0.0 MiB           1       # Sorts the dictionary by values in descending order
#     28
#     29                                             return emojis_dict.most_common(10)

# %% [markdown]
# ## 3.2 Análisis de resultados
#
# Teniendo en cuenta las dos celdas de abajo, se evidenciaron buenos resultados para las optimizaciones. Hay menores tiempos de memoria para el método optimizado para memoria, y también menor tiempo para el método de tiempo. Aún así, en promedio la diferencia de ambas aun no es muy notable comparado con el método opuesto, pero a medida que crezca el volumen de datos las dos diferencias tendrán un mayor relevancia en su desempeño.
#
# Se puede observar en promedio un consumo de memoria de q2_time de 110MiB vs 109.6 MiB para q2_memory en promedio.
# Por otro lado, para q2_time se ve un tiempo de 15.36 segundos vs 15.43 segundos para q2_memory en promedio.

# %%
cProfile.run('q2_time(file_path=file_path)')
# Out:
# Filename: c:\Users\sestupinan\Documents\latam\latam-challenge-sestupinan\src\q2_time.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#      8    109.9 MiB    109.9 MiB           1   @profile
#      9                                         def q2_time(file_path: str) -> List[Tuple[str, int]]:
#     10
#     11                                             # Regex pattern for emojis
#     12    109.9 MiB      0.0 MiB           1       emoji_pattern = re.compile(r'[\U0001F300-\U0001F6FF\U0001F900-\U0001F9FF\u2600-\u26FF\u2700-\u27BF]', flags=re.UNICODE)
#     13
#     14    109.9 MiB      0.0 MiB           1       emojis_dict = Counter()
#     15    109.9 MiB     -0.4 MiB           2       with open(file_path) as f:
#     16    110.0 MiB -53279.7 MiB      117408               for jsonObj in f:
#     17    110.0 MiB -53279.3 MiB      117407                   tweetDict = json.loads(jsonObj)
#     18                                                         # Uses the regex previously created to find all the emojis in the tweet content
#     19    110.0 MiB -53279.3 MiB      117407                   emojis = emoji_pattern.findall(tweetDict['content'])
#     20    110.0 MiB -72481.4 MiB      162711                   for emoji in emojis:
#     21                                                             # Sums 1 to the quantity of appereances of the emoji if it already exists
#     22    110.0 MiB -19202.1 MiB       45304                       if emojis_dict.get(emoji) is not None:
#     23    110.0 MiB -19005.4 MiB       44691                           emojis_dict[emoji] = emojis_dict[emoji] + 1
#     24                                                             # Adds the emoji to the dictionary and sets the value to 1 if it did not exist
#     25                                                             else:
#     26    110.0 MiB   -196.7 MiB         613                           emojis_dict[emoji] = 1
#     27
#     28                                             # Sorts the dictionary by values in descending order
#     29                                             emojis_dict.most_common(10)
#
#
#          1437855 function calls in 15.367 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       151    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000   15.366   15.366 <string>:1(<module>)
#    117407    0.535    0.000    3.420    0.000 __init__.py:299(loads)
#         1    0.000    0.000    0.000    0.000 __init__.py:565(__init__)
#         1    0.000    0.000    0.001    0.001 __init__.py:588(most_common)
#         1    0.000    0.000    0.000    0.000 __init__.py:640(update)
#         1    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:102(__init__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:130(__enter__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:139(__exit__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:279(helper)
#         1    0.000    0.000    0.000    0.000 coroutines.py:164(iscoroutinefunction)
#     49772    0.067    0.000    0.803    0.000 cp1252.py:22(decode)
#    117407    0.476    0.000    2.852    0.000 decoder.py:332(decode)
#    117407    2.255    0.000    2.255    0.000 decoder.py:343(raw_decode)
#         1    0.000    0.000    0.000    0.000 enum.py:801(value)
#         1    0.000    0.000    0.000    0.000 functools.py:421(_unwrap_partial)
#         2    0.000    0.000    0.000    0.000 genericpath.py:16(exists)
#         1    0.001    0.001    0.001    0.001 heapq.py:521(nlargest)
#         1    0.000    0.000    0.000    0.000 heapq.py:563(<listcomp>)
#         1    0.000    0.000    0.000    0.000 heapq.py:577(<listcomp>)
#         1    0.000    0.000    0.000    0.000 inspect.py:1049(__init__)
#       151    0.000    0.000    0.000    0.000 inspect.py:1058(tokeneater)
#         1    0.000    0.000    0.001    0.001 inspect.py:1101(getblock)
#         1    0.000    0.000    0.001    0.001 inspect.py:1112(getsourcelines)
#         4    0.000    0.000    0.000    0.000 inspect.py:182(ismodule)
#         2    0.000    0.000    0.000    0.000 inspect.py:191(isclass)
#         3    0.000    0.000    0.000    0.000 inspect.py:199(ismethod)
#         3    0.000    0.000    0.000    0.000 inspect.py:277(isfunction)
#         1    0.000    0.000    0.000    0.000 inspect.py:290(_has_code_flag)
#         1    0.000    0.000    0.000    0.000 inspect.py:308(iscoroutinefunction)
#         3    0.000    0.000    0.000    0.000 inspect.py:355(istraceback)
#         3    0.000    0.000    0.000    0.000 inspect.py:365(isframe)
#         8    0.000    0.000    0.000    0.000 inspect.py:379(iscode)
#         1    0.000    0.000    0.000    0.000 inspect.py:612(unwrap)
#         1    0.000    0.000    0.000    0.000 inspect.py:629(_is_wrapper)
#         1    0.000    0.000    0.000    0.000 inspect.py:773(getfile)
#         1    0.000    0.000    0.000    0.000 inspect.py:813(getsourcefile)
#         3    0.000    0.000    0.000    0.000 inspect.py:820(<genexpr>)
#         3    0.000    0.000    0.000    0.000 inspect.py:823(<genexpr>)
#         1    0.000    0.000    0.000    0.000 inspect.py:838(getabsfile)
#         1    0.000    0.000    0.000    0.000 inspect.py:850(getmodule)
#         1    0.000    0.000    0.000    0.000 inspect.py:932(findsource)
#         1    0.000    0.000    0.000    0.000 iostream.py:125(_event_pipe)
#         1    0.000    0.000    0.000    0.000 iostream.py:241(schedule)
#        26    0.000    0.000    0.000    0.000 iostream.py:503(_is_master_process)
#        26    0.000    0.000    0.000    0.000 iostream.py:530(_schedule_flush)
#        26    0.000    0.000    0.000    0.000 iostream.py:608(write)
#         2    0.000    0.000    0.000    0.000 linecache.py:36(getlines)
#         1    0.000    0.000    0.000    0.000 linecache.py:52(checkcache)
#         1    0.000    0.000   15.366   15.366 memory_profiler.py:1185(wrapper)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:1201(choose_backend)
#         6    0.000    0.000    0.000    0.000 memory_profiler.py:1215(<genexpr>)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:640(__init__)
#         1    0.000    0.000    0.001    0.001 memory_profiler.py:645(add)
#         2    0.000    0.000    0.000    0.000 memory_profiler.py:689(items)
#        23    0.000    0.000    0.000    0.000 memory_profiler.py:695(<genexpr>)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:702(__init__)
#         1    0.000    0.000    0.001    0.001 memory_profiler.py:713(__call__)
#         1    0.000    0.000    0.001    0.001 memory_profiler.py:728(add_function)
#         2    0.000    0.000    0.000    0.000 memory_profiler.py:740(_count_ctxmgr)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:748(wrap_function)
#         1    0.000    0.000   15.365   15.365 memory_profiler.py:759(f)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:775(enable_by_count)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:782(disable_by_count)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:842(enable)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:849(disable)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:853(show_results)
#         1    0.000    0.000    0.000    0.000 ntpath.py:150(splitdrive)
#         1    0.000    0.000    0.000    0.000 ntpath.py:489(normpath)
#         1    0.000    0.000    0.000    0.000 ntpath.py:51(normcase)
#         1    0.000    0.000    0.000    0.000 ntpath.py:563(abspath)
#         1   11.002   11.002   15.365   15.365 q2_time.py:8(q2_time)
#         2    0.000    0.000    0.000    0.000 re.py:249(compile)
#         2    0.000    0.000    0.000    0.000 re.py:288(_compile)
#         1    0.000    0.000    0.000    0.000 socket.py:621(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1102(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1169(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:553(is_set)
#       152    0.000    0.000    0.000    0.000 tokenize.py:431(_tokenize)
#         1    0.000    0.000    0.000    0.000 tokenize.py:614(generate_tokens)
#         1    0.000    0.000    0.000    0.000 types.py:176(__get__)
#       151    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FF8D7F5C920}
#     49772    0.736    0.000    0.736    0.000 {built-in method _codecs.charmap_decode}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heapify}
#         6    0.000    0.000    0.000    0.000 {built-in method _heapq.heapreplace}
#         1    0.000    0.000    0.000    0.000 {built-in method _winapi.LCMapStringEx}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000   15.367   15.367 {built-in method builtins.exec}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#    117465    0.010    0.000    0.010    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#    117489    0.012    0.000    0.012    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 {built-in method nt._getfullpathname}
#         3    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#        26    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         3    0.000    0.000    0.000    0.000 {built-in method nt.stat}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.gettrace}
#         2    0.000    0.000    0.000    0.000 {built-in method sys.settrace}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#        26    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         7    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    234814    0.021    0.000    0.021    0.000 {method 'end' of 're.Match' objects}
#         5    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#    117407    0.126    0.000    0.126    0.000 {method 'findall' of 're.Pattern' objects}
#        46    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#     45331    0.012    0.000    0.012    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#       107    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#    234941    0.088    0.000    0.088    0.000 {method 'match' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#       126    0.000    0.000    0.000    0.000 {method 'span' of 're.Match' objects}
#         1    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#    117409    0.023    0.000    0.023    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        26    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
cProfile.run('q2_memory(file_path=file_path)')
# Out:
# Filename: c:\Users\sestupinan\Documents\latam\latam-challenge-sestupinan\src\q2_memory.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#      7    109.6 MiB    109.6 MiB           1   @profile
#      8                                         def q2_memory(file_path: str) -> List[Tuple[str, int]]:
#      9
#     10    109.6 MiB      0.0 MiB           1       # Regex pattern for emojis
#     11                                             emoji_pattern = re.compile(r'[\U0001F300-\U0001F6FF\U0001F900-\U0001F9FF\u2600-\u26FF\u2700-\u27BF]', flags=re.UNICODE)
#     12    109.6 MiB      0.0 MiB           1
#     13    109.6 MiB     -0.0 MiB           2       emojis_dict = Counter()
#     14    109.6 MiB   -432.0 MiB      117408       with open(file_path) as f:
#     15    109.6 MiB   -432.0 MiB      117407               for jsonObj in f:
#     16                                                         tweetDict = json.loads(jsonObj)
#     17    109.6 MiB   -432.0 MiB      117407                   # Uses the regex previously created to find all the emojis in the tweet content
#     18    109.6 MiB   -589.0 MiB      162711                   emojis = emoji_pattern.findall(tweetDict['content'])
#     19                                                         for emoji in emojis:
#     20    109.6 MiB   -157.0 MiB       45304                       # Sums 1 to the quantity of appereances of the emoji if it already exists
#     21    109.6 MiB   -155.7 MiB       44691                       if emojis_dict.get(emoji) is not None:
#     22                                                                 emojis_dict[emoji] = emojis_dict[emoji] + 1
#     23                                                             # Adds the emoji to the dictionary and sets the value to 1 if it did not exist
#     24    109.6 MiB     -1.3 MiB         613                       else:
#     25                                                                 emojis_dict[emoji] = 1
#     26
#     27    109.6 MiB      0.0 MiB           1       # Sorts the dictionary by values in descending order
#     28
#     29                                             return emojis_dict.most_common(10)
#
#
#          1437881 function calls in 15.231 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       153    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000   15.231   15.231 <string>:1(<module>)
#    117407    0.542    0.000    3.357    0.000 __init__.py:299(loads)
#         1    0.000    0.000    0.000    0.000 __init__.py:565(__init__)
#         1    0.000    0.000    0.001    0.001 __init__.py:588(most_common)
#         1    0.000    0.000    0.000    0.000 __init__.py:640(update)
#         1    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:102(__init__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:130(__enter__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:139(__exit__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:279(helper)
#         1    0.000    0.000    0.000    0.000 coroutines.py:164(iscoroutinefunction)
#     49772    0.068    0.000    0.809    0.000 cp1252.py:22(decode)
#    117407    0.455    0.000    2.782    0.000 decoder.py:332(decode)
#    117407    2.206    0.000    2.206    0.000 decoder.py:343(raw_decode)
#         1    0.000    0.000    0.000    0.000 enum.py:801(value)
#         1    0.000    0.000    0.000    0.000 functools.py:421(_unwrap_partial)
#         2    0.000    0.000    0.000    0.000 genericpath.py:16(exists)
#         1    0.001    0.001    0.001    0.001 heapq.py:521(nlargest)
#         1    0.000    0.000    0.000    0.000 heapq.py:563(<listcomp>)
#         1    0.000    0.000    0.000    0.000 heapq.py:577(<listcomp>)
#         1    0.000    0.000    0.000    0.000 inspect.py:1049(__init__)
#       153    0.000    0.000    0.000    0.000 inspect.py:1058(tokeneater)
#         1    0.000    0.000    0.001    0.001 inspect.py:1101(getblock)
#         1    0.000    0.000    0.001    0.001 inspect.py:1112(getsourcelines)
#         4    0.000    0.000    0.000    0.000 inspect.py:182(ismodule)
#         2    0.000    0.000    0.000    0.000 inspect.py:191(isclass)
#         3    0.000    0.000    0.000    0.000 inspect.py:199(ismethod)
#         3    0.000    0.000    0.000    0.000 inspect.py:277(isfunction)
#         1    0.000    0.000    0.000    0.000 inspect.py:290(_has_code_flag)
#         1    0.000    0.000    0.000    0.000 inspect.py:308(iscoroutinefunction)
#         3    0.000    0.000    0.000    0.000 inspect.py:355(istraceback)
#         3    0.000    0.000    0.000    0.000 inspect.py:365(isframe)
#         8    0.000    0.000    0.000    0.000 inspect.py:379(iscode)
#         1    0.000    0.000    0.000    0.000 inspect.py:612(unwrap)
#         1    0.000    0.000    0.000    0.000 inspect.py:629(_is_wrapper)
#         1    0.000    0.000    0.000    0.000 inspect.py:773(getfile)
#         1    0.000    0.000    0.000    0.000 inspect.py:813(getsourcefile)
#         3    0.000    0.000    0.000    0.000 inspect.py:820(<genexpr>)
#         3    0.000    0.000    0.000    0.000 inspect.py:823(<genexpr>)
#         1    0.000    0.000    0.000    0.000 inspect.py:838(getabsfile)
#         1    0.000    0.000    0.000    0.000 inspect.py:850(getmodule)
#         1    0.000    0.000    0.000    0.000 inspect.py:932(findsource)
#         1    0.000    0.000    0.000    0.000 iostream.py:125(_event_pipe)
#         1    0.000    0.000    0.000    0.000 iostream.py:241(schedule)
#        27    0.000    0.000    0.000    0.000 iostream.py:503(_is_master_process)
#        27    0.000    0.000    0.000    0.000 iostream.py:530(_schedule_flush)
#        27    0.000    0.000    0.000    0.000 iostream.py:608(write)
#         2    0.000    0.000    0.000    0.000 linecache.py:36(getlines)
#         1    0.000    0.000    0.000    0.000 linecache.py:52(checkcache)
#         1    0.000    0.000   15.231   15.231 memory_profiler.py:1185(wrapper)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:1201(choose_backend)
#         6    0.000    0.000    0.000    0.000 memory_profiler.py:1215(<genexpr>)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:640(__init__)
#         1    0.000    0.000    0.001    0.001 memory_profiler.py:645(add)
#         2    0.000    0.000    0.000    0.000 memory_profiler.py:689(items)
#        24    0.000    0.000    0.000    0.000 memory_profiler.py:695(<genexpr>)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:702(__init__)
#         1    0.000    0.000    0.001    0.001 memory_profiler.py:713(__call__)
#         1    0.000    0.000    0.001    0.001 memory_profiler.py:728(add_function)
#         2    0.000    0.000    0.000    0.000 memory_profiler.py:740(_count_ctxmgr)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:748(wrap_function)
#         1    0.000    0.000   15.229   15.229 memory_profiler.py:759(f)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:775(enable_by_count)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:782(disable_by_count)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:842(enable)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:849(disable)
#         1    0.000    0.000    0.000    0.000 memory_profiler.py:853(show_results)
#         1    0.000    0.000    0.000    0.000 ntpath.py:150(splitdrive)
#         1    0.000    0.000    0.000    0.000 ntpath.py:489(normpath)
#         1    0.000    0.000    0.000    0.000 ntpath.py:51(normcase)
#         1    0.000    0.000    0.000    0.000 ntpath.py:563(abspath)
#         1   10.924   10.924   15.229   15.229 q2_memory.py:7(q2_memory)
#         2    0.000    0.000    0.000    0.000 re.py:249(compile)
#         2    0.000    0.000    0.000    0.000 re.py:288(_compile)
#         1    0.000    0.000    0.000    0.000 socket.py:621(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1102(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1169(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:553(is_set)
#       154    0.000    0.000    0.000    0.000 tokenize.py:431(_tokenize)
#         1    0.000    0.000    0.000    0.000 tokenize.py:614(generate_tokens)
#         1    0.000    0.000    0.000    0.000 types.py:176(__get__)
#       153    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FF8D7F5C920}
#     49772    0.741    0.000    0.741    0.000 {built-in method _codecs.charmap_decode}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heapify}
#         6    0.000    0.000    0.000    0.000 {built-in method _heapq.heapreplace}
#         1    0.000    0.000    0.000    0.000 {built-in method _winapi.LCMapStringEx}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000   15.231   15.231 {built-in method builtins.exec}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#    117466    0.010    0.000    0.010    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#    117492    0.011    0.000    0.011    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.001    0.001    0.001    0.001 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 {built-in method nt._getfullpathname}
#         3    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#        27    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         3    0.000    0.000    0.000    0.000 {built-in method nt.stat}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.gettrace}
#         2    0.000    0.000    0.000    0.000 {built-in method sys.settrace}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#        27    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         7    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    234814    0.021    0.000    0.021    0.000 {method 'end' of 're.Match' objects}
#         5    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#    117407    0.125    0.000    0.125    0.000 {method 'findall' of 're.Pattern' objects}
#        49    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#     45332    0.012    0.000    0.012    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#       108    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#    234942    0.087    0.000    0.087    0.000 {method 'match' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#       127    0.000    0.000    0.000    0.000 {method 'span' of 're.Match' objects}
#         1    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#    117409    0.023    0.000    0.023    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        27    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
# %load_ext memory_profiler
# %mprun -f q1_time q1_time(file_path)
# %mprun -f q1_memory q1_memory(file_path)
# Out:
# Filename: c:\Users\sestupinan\Documents\latam\latam-challenge-sestupinan\src\q1_time.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#      7    136.8 MiB    136.8 MiB           1   @profile
#      8                                         def q1_time(file_path: str) -> List[Tuple[datetime.date, str]]:
#      9
#     10                                             # Data loading
#     11   1590.1 MiB   1453.3 MiB           1       df = pd.read_json(file_path, lines=True)
#     12
#     13                                             # Create a date column using the datetime provided
#     14   1595.6 MiB      5.4 MiB           1       df['date_t'] = pd.to_datetime(df['date']).dt.date
#     15
#     16                                             # Compute the top 10 days with the most posts
#     17   1596.8 MiB      1.2 MiB           1       max_days = df.groupby("date_t").size().nlargest(10)
#     18
#     19                                             # Compute the top 10 days with the most posts
#     20   1598.8 MiB      2.0 MiB           1       df_usernames = pd.concat([df[['date_t']], df['user'].str['username']], axis = 1)
#     21
#     22                                             # Compute the top users with the most posts per day
#     23   1601.3 MiB      2.6 MiB           1       max_users = df_usernames.groupby(["date_t","user"]).size()
#     24
#     25                                             # Extract the top users only for the top 10 days
#     26   1601.3 MiB      0.0 MiB           1       most_repeated_users_per_day = []
#     27   1601.7 MiB      0.0 MiB          11       for date in max_days.index:
#     28   1601.7 MiB      0.4 MiB          10           most_repeated_users_per_day.append((date, max_users[date].idxmax()))
#     29   1601.7 MiB      0.0 MiB           1       return most_repeated_users_per_day
# Filename: c:\Users\sestupinan\Documents\latam\latam-challenge-sestupinan\src\q1_memory.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#      1                                         from typing import List, Tuple
#      2                                         from datetime import datetime
#      3                                         import json
#      4                                         from datetime import datetime
#      5                                         from collections import defaultdict
#      6   1593.6 MiB   1593.6 MiB           1
#      7   1593.6 MiB      0.0 MiB           1   def q1_memory(file_path: str) -> List[Tuple[datetime.date, str]]:
#      8   1593.6 MiB   -325.9 MiB           2       date_list = defaultdict(int)
#      9   1593.6 MiB -103987385.8 MiB      117408       user_date_list = defaultdict(int)
#     10   1593.6 MiB -103987463.4 MiB      117407       #"2021-02-24T09:22:34+00:00"
#     11   1593.6 MiB -103987415.9 MiB      117407       #format = '%Y-%m-%dT%H:%M:%S+00:00'
#     12                                             format = '%Y-%m-%d'
#     13                                             with open(file_path) as f:
#     14   2637.0 MiB   1043.4 MiB           1           for jsonObj in f:
#     15                                                     tweetDict = json.loads(jsonObj)
#     16                                                     formatted_date = datetime.strptime(tweetDict['date'].split('T')[0], format).date()
#     17   2642.9 MiB      5.9 MiB           1               username = tweetDict['user']['username']
#     18                                                     date_list[formatted_date] +=1
#     19                                                     user_date_list[(formatted_date, username)]+=1
#     20   2644.5 MiB      1.6 MiB           1
#     21                                             # Sorts the dictionary by values in descending order
#     22                                             date_list = sorted(date_list.items(), key=lambda x: x[1], reverse=True)
#     23   2646.7 MiB      2.2 MiB           1
#     24                                             # Extracts the top 10 emojis
#     25                                             date_list = date_list[:10]
#     26   2652.3 MiB      5.6 MiB           1
#     27                                             listed = []
#     28                                             for date, n in date_list:
#     29   2652.3 MiB      0.0 MiB           1           max_tweets = 0
#     30   2652.6 MiB     -0.0 MiB          11           max_user = ''
#     31   2652.6 MiB      0.3 MiB          10           for (tweet_date, username), count in user_date_list.items():
#     32   2652.6 MiB      0.0 MiB           1               if tweet_date == date and count > max_tweets:
#     33                                                         max_tweets = count
#     34                                                         max_user = username
#     35                                                 listed.append((date, max_user))
#     36                                             return listed
